# %% [markdown]
# **Text Generation with Neural Networks**

# %% [markdown]
# **Functions for Processing Text**

# %% [markdown]
# Reading in files as a string text

# %%
def read_file(file):
  with open(file) as f:
    str_text = f.read()

    return str_text

# %% [markdown]
# **Tokenize and Clean Text**

# %%
import spacy

# %%
nlp = spacy.load("en",disable=["parser","tagger","ner"])

# %%
nlp.max_length = 1198623

# %%
def seperate_punc(doc_text):
  return[token.text.lower() for token in nlp(doc_text) if token.text not in '\n\n \n\n\n!"-#$%&()--.*+,-/:;<=>?@[\\]^_`{|}~\t\n ']

# %%
d = read_file("moby_dick_four_chapters.txt")

# %%
tokens = seperate_punc(d)

# %%
len(tokens)
# Out:
# 11338

# %% [markdown]
# **Create Sequences of Tokens**

# %%
#25 words --- network predict #26 word

# %%
# organize into sequences of tokens
train_length = 25 + 1 # 25 training words , then one target word

# Empty list of sequences
text_sequences = []

for i in range(train_length,len(tokens)):
  seq = tokens[i-train_length:i]  # Grab train_len# amount of characters

   # Add to list of sequences
  text_sequences.append(seq)

# %%
" ".join(text_sequences[0])
# Out:
# 'call me ishmael some years ago never mind how long precisely having little or no money in my purse and nothing particular to interest me on'

# %%
" ".join(text_sequences[1])
# Out:
# 'me ishmael some years ago never mind how long precisely having little or no money in my purse and nothing particular to interest me on shore'

# %% [markdown]
# **Keras Tokenization**

# %%
from keras.preprocessing.text import Tokenizer

# %%
# integer encode sequences of words
tokenizer = Tokenizer()

tokenizer.fit_on_texts(text_sequences)

# %%
sequences = tokenizer.texts_to_sequences(text_sequences)

# %%
sequences[0]
# Out:
# [956,
#  14,
#  263,
#  51,
#  261,
#  408,
#  87,
#  219,
#  129,
#  111,
#  954,
#  260,
#  50,
#  43,
#  38,
#  315,
#  7,
#  23,
#  546,
#  3,
#  150,
#  259,
#  6,
#  2712,
#  14,
#  24]

# %%
tokenizer.index_word
# Out:
# {1: 'the',
#  2: 'a',
#  3: 'and',
#  4: 'of',
#  5: 'i',
#  6: 'to',
#  7: 'in',
#  8: 'it',
#  9: 'that',
#  10: 'he',
#  11: 'his',
#  12: 'was',
#  13: 'but',
#  14: 'me',
#  15: 'with',
#  16: 'as',
#  17: 'at',
#  18: 'this',
#  19: 'you',
#  20: 'is',
#  21: 'all',
#  22: 'for',
#  23: 'my',
#  24: 'on',
#  25: 'be',
#  26: "'s",
#  27: 'not',
#  28: 'from',
#  29: 'there',
#  30: 'one',
#  31: 'up',
#  32: 'what',
#  33: 'him',
#  34: 'so',
#  35: 'bed',
#  36: 'now',
#  37: 'about',
#  38: 'no',
#  39: 'into',
#  40: 'by',
#  41: 'were',
#  42: 'out',
#  43: 'or',
#  44: 'harpooneer',
#  45: 'had',
#  46: 'then',
#  47: 'have',
#  48: 'an',
#  49: 'upon',
#  50: 'little',
#  51: 'some',
#  52: 'old',
#  53: 'like',
#  54: 'if',
#  55: 'they',
#  56: 'would',
#  57: 'do',
#  58: 'over',
#  59: 'landlord',
#  60: 'thought',
#  61: 'room',
#  62: 'when',
#  63: 'could',
#  64: "n't",
#  65: 'night',
#  66: 'here',
#  67: 'head',
#  68: 'such',
#  69: 'which',
#  70: 'man',
#  71: 'did',
#  72: 'sea',
#  73: 'time',
#  74: 'other',
#  75: 'very',
#  76: 'go',
#  77: 'these',
#  78: 'more',
#  79: 'though',
#  80: 'first',
#  81: 'sort',
#  82: 'said',
#  83: 'last',
#  84: 'down',
#  85: 'most',
#  86: 'been',
#  87: 'never',
#  88: 'your',
#  89: 'them',
#  90: 'must',
#  91: 'tell',
#  92: 'much',
#  93: 'good',
#  94: 'see',
#  95: 'off',
#  96: 'myself',
#  97: 'are',
#  98: 'yet',
#  99: 'sleep',
#  100: 'who',
#  101: 'seemed',
#  102: 'light',
#  103: 'way',
#  104: 'their',
#  105: 'just',
#  106: 'being',
#  107: 'than',
#  108: 'place',
#  109: 'queequeg',
#  110: 'great',
#  111: 'long',
#  112: 'before',
#  113: 'get',
#  114: 'round',
#  115: 'where',
#  116: 'still',
#  117: 'any',
#  118: 'too',
#  119: 'only',
#  120: 'door',
#  121: 'can',
#  122: 'himself',
#  123: 'heads',
#  124: 'come',
#  125: 'ever',
#  126: 'two',
#  127: 'enough',
#  128: 'made',
#  129: 'how',
#  130: 'hand',
#  131: 'same',
#  132: 'looking',
#  133: 'something',
#  134: 'may',
#  135: "'",
#  136: 'almost',
#  137: 'say',
#  138: 'should',
#  139: 'side',
#  140: 'why',
#  141: 'own',
#  142: 'we',
#  143: 'new',
#  144: 'again',
#  145: 'came',
#  146: 'arm',
#  147: 'house',
#  148: 'away',
#  149: 'might',
#  150: 'nothing',
#  151: 'take',
#  152: 'towards',
#  153: 'will',
#  154: 'under',
#  155: 'going',
#  156: 'make',
#  157: 'whale',
#  158: 'stood',
#  159: 'boots',
#  160: 'ye',
#  161: 'back',
#  162: "'ll",
#  163: 'tomahawk',
#  164: 'part',
#  165: 'world',
#  166: 'soon',
#  167: 'water',
#  168: 'against',
#  169: 'those',
#  170: 'between',
#  171: 'after',
#  172: 'whaling',
#  173: 'lay',
#  174: 'took',
#  175: 'half',
#  176: 'began',
#  177: 'face',
#  178: 'streets',
#  179: 'land',
#  180: 'better',
#  181: 'once',
#  182: 'voyage',
#  183: 'give',
#  184: 'rather',
#  185: 'well',
#  186: 'however',
#  187: 'else',
#  188: 'heard',
#  189: 'put',
#  190: 'stop',
#  191: 'dark',
#  192: 'went',
#  193: 'black',
#  194: 'window',
#  195: 'cannibal',
#  196: 'fire',
#  197: 'every',
#  198: 'ship',
#  199: 'stand',
#  200: 'strange',
#  201: 'without',
#  202: 'feet',
#  203: 'whether',
#  204: 'because',
#  205: 'eyes',
#  206: 'think',
#  207: 'thinks',
#  208: 'idea',
#  209: 'bag',
#  210: 'nantucket',
#  211: 'late',
#  212: 'cold',
#  213: 'our',
#  214: 'found',
#  215: 'full',
#  216: 'morning',
#  217: 'sleeping',
#  218: 'got',
#  219: 'mind',
#  220: 'her',
#  221: 'right',
#  222: 'its',
#  223: 'look',
#  224: 'town',
#  225: 'south',
#  226: 'does',
#  227: 'let',
#  228: 'set',
#  229: 'yourself',
#  230: 'image',
#  231: 'saw',
#  232: 'am',
#  233: 'besides',
#  234: 'sailor',
#  235: 'seas',
#  236: 'rolled',
#  237: 'till',
#  238: 'day',
#  239: 'sign',
#  240: 'looked',
#  241: 'hard',
#  242: 'moment',
#  243: 'corner',
#  244: 'entry',
#  245: 'four',
#  246: 'wall',
#  247: 'savage',
#  248: 'table',
#  249: 'indeed',
#  250: 'bench',
#  251: 'chest',
#  252: 'while',
#  253: 'stranger',
#  254: 'possible',
#  255: 'feeling',
#  256: 'floor',
#  257: 'squares',
#  258: 'hat',
#  259: 'particular',
#  260: 'having',
#  261: 'years',
#  262: 'harpoon',
#  263: 'ishmael',
#  264: 'whenever',
#  265: 'mouth',
#  266: 'high',
#  267: 'knew',
#  268: 'men',
#  269: 'hours',
#  270: 'green',
#  271: 'bit',
#  272: 'within',
#  273: 'picture',
#  274: 'told',
#  275: 'story',
#  276: 'mean',
#  277: 'speak',
#  278: 'order',
#  279: 'making',
#  280: 'even',
#  281: 'perhaps',
#  282: 'things',
#  283: 'answer',
#  284: 'parts',
#  285: 'wild',
#  286: 'reason',
#  287: 'young',
#  288: 'craft',
#  289: 'business',
#  290: 'dead',
#  291: 'another',
#  292: 'middle',
#  293: 'sure',
#  294: 'candle',
#  295: 'presently',
#  296: 'low',
#  297: 'turned',
#  298: 'teeth',
#  299: 'dim',
#  300: 'euroclydon',
#  301: 'kept',
#  302: 'glass',
#  303: 'afterwards',
#  304: 'large',
#  305: 'three',
#  306: 'telling',
#  307: 'getting',
#  308: 'small',
#  309: 'next',
#  310: 'seeing',
#  311: 'sell',
#  312: 'felt',
#  313: 'sun',
#  314: 'e',
#  315: 'money',
#  316: 'sail',
#  317: 'coffin',
#  318: 'especially',
#  319: 'street',
#  320: 'city',
#  321: 'few',
#  322: 'previous',
#  323: 'sight',
#  324: 'days',
#  325: 'straight',
#  326: 'nigh',
#  327: 'legs',
#  328: 'try',
#  329: 'yes',
#  330: 'unless',
#  331: 'poor',
#  332: 'coat',
#  333: 'passenger',
#  334: 'taking',
#  335: 'true',
#  336: 'thing',
#  337: 'ai',
#  338: 'always',
#  339: 'us',
#  340: 'really',
#  341: 'marvellous',
#  342: 'heaven',
#  343: 'air',
#  344: 'far',
#  345: 'second',
#  346: 'many',
#  347: 'has',
#  348: 'unaccountable',
#  349: 'grand',
#  350: 'jolly',
#  351: 'open',
#  352: 'shirt',
#  353: 'cape',
#  354: 'bedford',
#  355: 'fine',
#  356: 'further',
#  357: 'ice',
#  358: 'frost',
#  359: 'foot',
#  360: 'wide',
#  361: 'white',
#  362: 'tall',
#  363: 'i.',
#  364: 'wooden',
#  365: 'worse',
#  366: 'death',
#  367: 'mine',
#  368: 'lazarus',
#  369: 'keep',
#  370: 'along',
#  371: 'hung',
#  372: 'throwing',
#  373: 'centre',
#  374: 'rest',
#  375: 'fact',
#  376: 'hair',
#  377: 'broken',
#  378: 'kill',
#  379: 'through',
#  380: 'chimney',
#  381: 'fancy',
#  382: 'bar',
#  383: 'trying',
#  384: 'dumplings',
#  385: 'heavens',
#  386: 'manner',
#  387: 'devil',
#  388: 'together',
#  389: 'seen',
#  390: 'deal',
#  391: 'know',
#  392: 'skin',
#  393: 'ca',
#  394: 'shavings',
#  395: 'peddling',
#  396: 'sunday',
#  397: 'counterpane',
#  398: 'mat',
#  399: 'christian',
#  400: 'commenced',
#  401: 'thinking',
#  402: 'similar',
#  403: 'afraid',
#  404: 'length',
#  405: 'idol',
#  406: 'sabbee',
#  407: 'waking',
#  408: 'ago',
#  409: 'find',
#  410: 'damp',
#  411: 'soul',
#  412: 'strong',
#  413: 'account',
#  414: 'sword',
#  415: 'quietly',
#  416: 'degree',
#  417: 'left',
#  418: 'around',
#  419: 'fixed',
#  420: 'ships',
#  421: 'miles',
#  422: 'country',
#  423: 'stream',
#  424: 'lead',
#  425: 'american',
#  426: 'artist',
#  427: 'each',
#  428: 'goes',
#  429: 'deep',
#  430: 'distant',
#  431: 'winds',
#  432: 'blue',
#  433: 'among',
#  434: 'suddenly',
#  435: 'feel',
#  436: 'meaning',
#  437: 'phantom',
#  438: 'life',
#  439: 'passengers',
#  440: 'nor',
#  441: 'kind',
#  442: 'quite',
#  443: 'care',
#  444: 'board',
#  445: 'somehow',
#  446: 'broiled',
#  447: 'mast',
#  448: 'sense',
#  449: 'knowing',
#  450: 'either',
#  451: 'passed',
#  452: 'hands',
#  453: 'paying',
#  454: 'pay',
#  455: 'penny',
#  456: 'sailors',
#  457: 'exactly',
#  458: 'short',
#  459: 'easy',
#  460: 'portentous',
#  461: 'island',
#  462: 'nameless',
#  463: 'sounds',
#  464: 'since',
#  465: 'snow',
#  466: 'saturday',
#  467: 'matter',
#  468: 'red',
#  469: 'partly',
#  470: 'ere',
#  471: 'became',
#  472: 'meanwhile',
#  473: 'pocket',
#  474: 'darkness',
#  475: 'fish',
#  476: 'inn',
#  477: 'watch',
#  478: 'broad',
#  479: 'entering',
#  480: 'ha',
#  481: 'ashes',
#  482: 'opened',
#  483: 'spouter',
#  484: 'name',
#  485: 'suppose',
#  486: 'quiet',
#  487: 'best',
#  488: 'tempestuous',
#  489: 'says',
#  490: 'thou',
#  491: 'both',
#  492: 'occurred',
#  493: 'dives',
#  494: 'holding',
#  495: 'frozen',
#  496: 'altogether',
#  497: 'plain',
#  498: 'whom',
#  499: 'clean',
#  500: 'human',
#  501: 'entered',
#  502: 'wrinkled',
#  503: 'shelf',
#  504: 'jonah',
#  505: 'blanket',
#  506: "goin'",
#  507: 'bitter',
#  508: 'supper',
#  509: 'sat',
#  510: 'settle',
#  511: 'chap',
#  512: 'help',
#  513: 'spend',
#  514: 'landed',
#  515: 'standing',
#  516: 'held',
#  517: 'somewhat',
#  518: 'sober',
#  519: 'whole',
#  520: 'dam',
#  521: 'brown',
#  522: 'bulkington',
#  523: "o'clock",
#  524: 'none',
#  525: 'coming',
#  526: "'ve",
#  527: 'wait',
#  528: 'plane',
#  529: 'saying',
#  530: 'grinning',
#  531: 'placed',
#  532: 'shouted',
#  533: 'bedfellow',
#  534: 'zealand',
#  535: 'sal',
#  536: 'wash',
#  537: 'thrown',
#  538: 'purplish',
#  539: 'turn',
#  540: 'completely',
#  541: 'fear',
#  542: 'grego',
#  543: 'baby',
#  544: 'slowly',
#  545: 'civilized',
#  546: 'purse',
#  547: 'monkey',
#  548: 'involuntarily',
#  549: 'pausing',
#  550: 'warehouses',
#  551: 'requires',
#  552: 'people',
#  553: 'nearly',
#  554: 'ocean',
#  555: 'indian',
#  556: 'waterward',
#  557: 'battery',
#  558: 'noble',
#  559: 'washed',
#  560: 'crowds',
#  561: 'sabbath',
#  562: 'afternoon',
#  563: 'thence',
#  564: 'silent',
#  565: 'thousands',
#  566: 'reveries',
#  567: 'leaning',
#  568: 'seated',
#  569: 'bulwarks',
#  570: 'aloft',
#  571: 'week',
#  572: 'plaster',
#  573: 'gone',
#  574: 'bound',
#  575: 'content',
#  576: 'yonder',
#  577: 'falling',
#  578: 'north',
#  579: 'please',
#  580: 'ten',
#  581: 'leaves',
#  582: 'magic',
#  583: 'plunged',
#  584: 'metaphysical',
#  585: 'chief',
#  586: 'trunk',
#  587: 'meadow',
#  588: 'smoke',
#  589: 'reaching',
#  590: 'hill',
#  591: 'thus',
#  592: 'pine',
#  593: 'sighs',
#  594: 'shepherd',
#  595: 'june',
#  596: 'scores',
#  597: 'thousand',
#  598: 'sadly',
#  599: 'robust',
#  600: 'healthy',
#  601: 'boy',
#  602: 'crazy',
#  603: 'hold',
#  604: 'holy',
#  605: 'brother',
#  606: 'ourselves',
#  607: 'begin',
#  608: 'grow',
#  609: 'inferred',
#  610: 'needs',
#  611: "don't",
#  612: 'themselves',
#  613: 'commodore',
#  614: 'captain',
#  615: 'cook',
#  616: 'glory',
#  617: 'whatsoever',
#  618: 'confess',
#  619: 'officer',
#  620: 'respectfully',
#  621: 'horse',
#  622: 'huge',
#  623: 'houses',
#  624: 'forecastle',
#  625: 'jump',
#  626: 'spar',
#  627: 'particularly',
#  628: 'putting',
#  629: 'tar',
#  630: 'schoolmaster',
#  631: 'boys',
#  632: 'transition',
#  633: 'grin',
#  634: 'bear',
#  635: 'hunks',
#  636: 'sweep',
#  637: 'weighed',
#  638: 'anything',
#  639: 'less',
#  640: 'thump',
#  641: 'point',
#  642: 'view',
#  643: 'single',
#  644: 'difference',
#  645: 'act',
#  646: 'uncomfortable',
#  647: 'compare',
#  648: 'earthly',
#  649: 'enter',
#  650: 'deck',
#  651: 'quarter',
#  652: 'leaders',
#  653: 'smelt',
#  654: 'fates',
#  655: 'doubtless',
#  656: 'formed',
#  657: 'run',
#  658: 'stage',
#  659: 'shabby',
#  660: 'others',
#  661: 'circumstances',
#  662: 'motives',
#  663: 'various',
#  664: 'mysterious',
#  665: 'curiosity',
#  666: 'tormented',
#  667: 'everlasting',
#  668: 'wonder',
#  669: 'purpose',
#  670: 'floated',
#  671: 'stuffed',
#  672: 'horn',
#  673: 'arrived',
#  674: 'offer',
#  675: 'following',
#  676: 'embark',
#  677: 'pleased',
#  678: 'original',
#  679: 'stranded',
#  680: 'leviathan',
#  681: 'whales',
#  682: 'nay',
#  683: 'dismal',
#  684: 'wherever',
#  685: 'dreary',
#  686: 'crossed',
#  687: 'expensive',
#  688: 'bright',
#  689: 'windows',
#  690: 'packed',
#  691: 'inches',
#  692: 'thick',
#  693: 'hear',
#  694: 'tinkling',
#  695: 'glasses',
#  696: 'blackness',
#  697: 'moving',
#  698: 'hour',
#  699: 'proved',
#  700: 'meant',
#  701: 'public',
#  702: 'box',
#  703: 'flying',
#  704: 'harpoons',
#  705: 'trap',
#  706: 'loud',
#  707: 'voice',
#  708: 'sitting',
#  709: 'beyond',
#  710: 'negro',
#  711: 'creaking',
#  712: 'swinging',
#  713: 'painting',
#  714: 'representing',
#  715: 'connexion',
#  716: 'peter',
#  717: 'itself',
#  718: 'carted',
#  719: 'burnt',
#  720: 'spot',
#  721: 'queer',
#  722: 'gable',
#  723: 'ended',
#  724: 'sharp',
#  725: 'wind',
#  726: 'howling',
#  727: 'nevertheless',
#  728: 'called',
#  729: 'outside',
#  730: 'passage',
#  731: 'body',
#  732: 'curbstone',
#  733: 'corn',
#  734: 'pooh',
#  735: 'northern',
#  736: 'lights',
#  737: 'summer',
#  738: 'lengthwise',
#  739: 'gods',
#  740: 'lie',
#  741: 'plenty',
#  742: 'study',
#  743: 'series',
#  744: 'arrive',
#  745: 'shadows',
#  746: 'dint',
#  747: 'conclusion',
#  748: 'confounded',
#  749: 'limber',
#  750: 'truly',
#  751: 'drive',
#  752: 'unimaginable',
#  753: 'midnight',
#  754: 'unnatural',
#  755: 'breaking',
#  756: 'design',
#  757: 'opposite',
#  758: 'monstrous',
#  759: 'knots',
#  760: 'vast',
#  761: 'handle',
#  762: 'wondered',
#  763: 'mixed',
#  764: 'deformed',
#  765: 'flung',
#  766: 'iron',
#  767: 'arched',
#  768: 'cut',
#  769: 'times',
#  770: 'beneath',
#  771: 'covered',
#  772: 'gathered',
#  773: 'stands',
#  774: 'rude',
#  775: 'bone',
#  776: 'abominable',
#  777: 'measure',
#  778: 'seamen',
#  779: 'skrimshander',
#  780: 'sought',
#  781: 'added',
#  782: 'forehead',
#  783: 'objections',
#  784: "'d",
#  785: 'used',
#  786: 'depend',
#  787: 'decent',
#  788: 'want',
#  789: 'ready',
#  790: 'working',
#  791: 'space',
#  792: 'lips',
#  793: 'fingers',
#  794: 'fare',
#  795: 'fellow',
#  796: 'nightmare',
#  797: 'nt',
#  798: 'complexioned',
#  799: 'eats',
#  800: "'em",
#  801: 'afore',
#  802: 'resolved',
#  803: 'noise',
#  804: 'offing',
#  805: 'shaggy',
#  806: 'woollen',
#  807: 'stiff',
#  808: 'labrador',
#  809: 'wake',
#  810: 'bad',
#  811: 'mounted',
#  812: 'generally',
#  813: 'shipmates',
#  814: 'become',
#  815: 'height',
#  816: 'seem',
#  817: 'plan',
#  818: 'private',
#  819: 'unknown',
#  820: 'apartment',
#  821: 'hammock',
#  822: 'linen',
#  823: 'home',
#  824: 'hole',
#  825: 'mattress',
#  826: 'planing',
#  827: 'knot',
#  828: 'near',
#  829: 'sake',
#  830: 'chair',
#  831: 'narrow',
#  832: 'leaving',
#  833: 'interval',
#  834: 'met',
#  835: 'inside',
#  836: 'violent',
#  837: 'ones',
#  838: 'comprehension',
#  839: 'bird',
#  840: 'airley',
#  841: 'airth',
#  842: 'engaged',
#  843: 'whittling',
#  844: 'guess',
#  845: 'done',
#  846: 'break',
#  847: 'broke',
#  848: 'understand',
#  849: 'certain',
#  850: 'demand',
#  851: 'selling',
#  852: 'sir',
#  853: 'string',
#  854: 'mystery',
#  855: 'showed',
#  856: 'dangerous',
#  857: 'flukes',
#  858: 'slept',
#  859: 'big',
#  860: 'sam',
#  861: 'lighted',
#  862: 'wo',
#  863: 'stairs',
#  864: 'placing',
#  865: 'double',
#  866: 'eyeing',
#  867: 'belonging',
#  868: 'papered',
#  869: 'parcel',
#  870: 'tried',
#  871: 'satisfactory',
#  872: 'concerning',
#  873: 'edges',
#  874: 'stuck',
#  875: 'gave',
#  876: 'neck',
#  877: 'sleeves',
#  878: 'undressed',
#  879: 'remembering',
#  880: 'jumped',
#  881: 'pantaloons',
#  882: 'blowing',
#  883: 'doze',
#  884: 'pretty',
#  885: 'heavy',
#  886: 'save',
#  887: 'infernal',
#  888: 'peddler',
#  889: 'yellow',
#  890: 'colour',
#  891: 'dreadfully',
#  892: 'sticking',
#  893: 'cheeks',
#  894: 'truth',
#  895: 'remembered',
#  896: 'whaleman',
#  897: 'tattooed',
#  898: 'concluded',
#  899: 'lying',
#  900: 'tanning',
#  901: 'hot',
#  902: 'produced',
#  903: 'beaver',
#  904: 'singing',
#  905: 'bolted',
#  906: 'arms',
#  907: 'running',
#  908: 'curious',
#  909: 'hunch',
#  910: 'congo',
#  911: 'ill',
#  912: 'takes',
#  913: 'biscuit',
#  914: 'top',
#  915: 'lamp',
#  916: 'succeeded',
#  917: 'polite',
#  918: 'guttural',
#  919: 'pagan',
#  920: 'spell',
#  921: 'tobacco',
#  922: 'grunt',
#  923: 'whatever',
#  924: 'ee',
#  925: 'horrid',
#  926: 'pipe',
#  927: 'smoking',
#  928: 'complied',
#  929: 'patchwork',
#  930: 'figure',
#  931: 'shade',
#  932: 'quilt',
#  933: 'hugging',
#  934: 'sensations',
#  935: 'explain',
#  936: 'remember',
#  937: 'circumstance',
#  938: 'reality',
#  939: 'stepmother',
#  940: 'sixteen',
#  941: 'abed',
#  942: 'troubled',
#  943: 'supernatural',
#  944: 'ages',
#  945: 'awful',
#  946: 'consciousness',
#  947: 'observing',
#  948: 'creature',
#  949: 'dress',
#  950: 'watching',
#  951: 'probably',
#  952: 'toilet',
#  953: 'wrapped',
#  954: 'precisely',
#  955: 'jacket',
#  956: 'call',
#  957: 'shore',
#  958: 'watery',
#  959: 'driving',
#  960: 'spleen',
#  961: 'regulating',
#  962: 'circulation',
#  963: 'growing',
#  964: 'grim',
#  965: 'drizzly',
#  966: 'november',
#  967: 'bringing',
#  968: 'rear',
#  969: 'funeral',
#  970: 'meet',
#  971: 'hypos',
#  972: 'upper',
#  973: 'moral',
#  974: 'principle',
#  975: 'prevent',
#  976: 'deliberately',
#  977: 'stepping',
#  978: 'methodically',
#  979: 'knocking',
#  980: 'hats',
#  981: 'substitute',
#  982: 'pistol',
#  983: 'ball',
#  984: 'philosophical',
#  985: 'flourish',
#  986: 'cato',
#  987: 'throws',
#  988: 'surprising',
#  989: 'cherish',
#  990: 'feelings',
#  991: 'insular',
#  992: 'manhattoes',
#  993: 'belted',
#  994: 'wharves',
#  995: 'isles',
#  996: 'coral',
#  997: 'reefs',
#  998: 'commerce',
#  999: 'surrounds',
#  1000: 'surf',
#  ...}

# %%
for i in sequences[0]:
  print(f"{i} : {tokenizer.index_word[i]}")
# Out:
# 956 : call
# 14 : me
# 263 : ishmael
# 51 : some
# 261 : years
# 408 : ago
# 87 : never
# 219 : mind
# 129 : how
# 111 : long
# 954 : precisely
# 260 : having
# 50 : little
# 43 : or
# 38 : no
# 315 : money
# 7 : in
# 23 : my
# 546 : purse
# 3 : and
# 150 : nothing
# 259 : particular
# 6 : to
# 2712 : interest
# 14 : me
# 24 : on

# %%
#Frequency of words
tokenizer.word_counts
# Out:
# OrderedDict([('call', 27),
#              ('me', 2471),
#              ('ishmael', 133),
#              ('some', 758),
#              ('years', 135),
#              ('ago', 84),
#              ('never', 449),
#              ('mind', 164),
#              ('how', 321),
#              ('long', 374),
#              ('precisely', 37),
#              ('having', 142),
#              ('little', 767),
#              ('or', 950),
#              ('no', 1003),
#              ('money', 120),
#              ('in', 5647),
#              ('my', 1786),
#              ('purse', 71),
#              ('and', 9646),
#              ('nothing', 281),
#              ('particular', 152),
#              ('to', 6497),
#              ('interest', 24),
#              ('on', 1716),
#              ('shore', 26),
#              ('i', 7150),
#              ('thought', 676),
#              ('would', 702),
#              ('sail', 104),
#              ('about', 1014),
#              ('a', 10377),
#              ('see', 416),
#              ('the', 15540),
#              ('watery', 26),
#              ('part', 234),
#              ('of', 8287),
#              ('world', 234),
#              ('it', 4238),
#              ('is', 1950),
#              ('way', 390),
#              ('have', 806),
#              ('driving', 26),
#              ('off', 416),
#              ('spleen', 26),
#              ('regulating', 26),
#              ('circulation', 26),
#              ('whenever', 130),
#              ('find', 78),
#              ('myself', 416),
#              ('growing', 26),
#              ('grim', 26),
#              ('mouth', 130),
#              ('damp', 78),
#              ('drizzly', 26),
#              ('november', 26),
#              ('soul', 78),
#              ('involuntarily', 52),
#              ('pausing', 52),
#              ('before', 364),
#              ('coffin', 104),
#              ('warehouses', 52),
#              ('bringing', 26),
#              ('up', 1237),
#              ('rear', 26),
#              ('every', 182),
#              ('funeral', 26),
#              ('meet', 26),
#              ('especially', 104),
#              ('hypos', 26),
#              ('get', 364),
#              ('such', 572),
#              ('an', 806),
#              ('upper', 26),
#              ('hand', 312),
#              ('that', 3770),
#              ('requires', 52),
#              ('strong', 78),
#              ('moral', 26),
#              ('principle', 26),
#              ('prevent', 26),
#              ('from', 1508),
#              ('deliberately', 26),
#              ('stepping', 26),
#              ('into', 988),
#              ('street', 104),
#              ('methodically', 26),
#              ('knocking', 26),
#              ('people', 52),
#              ("'s", 1691),
#              ('hats', 26),
#              ('then', 832),
#              ('account', 78),
#              ('high', 130),
#              ('time', 520),
#              ('sea', 546),
#              ('as', 2366),
#              ('soon', 234),
#              ('can', 338),
#              ('this', 2158),
#              ('substitute', 26),
#              ('for', 1820),
#              ('pistol', 26),
#              ('ball', 26),
#              ('with', 2392),
#              ('philosophical', 26),
#              ('flourish', 26),
#              ('cato', 26),
#              ('throws', 26),
#              ('himself', 338),
#              ('upon', 780),
#              ('his', 3139),
#              ('sword', 78),
#              ('quietly', 78),
#              ('take', 260),
#              ('ship', 182),
#              ('there', 1456),
#              ('surprising', 26),
#              ('if', 728),
#              ('they', 728),
#              ('but', 2652),
#              ('knew', 130),
#              ('almost', 286),
#              ('all', 1872),
#              ('men', 130),
#              ('their', 390),
#              ('degree', 78),
#              ('other', 494),
#              ('cherish', 26),
#              ('very', 494),
#              ('nearly', 52),
#              ('same', 312),
#              ('feelings', 26),
#              ('towards', 260),
#              ('ocean', 52),
#              ('now', 1040),
#              ('your', 442),
#              ('insular', 26),
#              ('city', 104),
#              ('manhattoes', 26),
#              ('belted', 26),
#              ('round', 364),
#              ('by', 962),
#              ('wharves', 26),
#              ('indian', 52),
#              ('isles', 26),
#              ('coral', 26),
#              ('reefs', 26),
#              ('commerce', 26),
#              ('surrounds', 26),
#              ('her', 156),
#              ('surf', 26),
#              ('right', 156),
#              ('left', 78),
#              ('streets', 208),
#              ('you', 2158),
#              ('waterward', 52),
#              ('its', 156),
#              ('extreme', 26),
#              ('downtown', 26),
#              ('battery', 52),
#              ('where', 364),
#              ('noble', 52),
#              ('mole', 26),
#              ('washed', 52),
#              ('waves', 26),
#              ('cooled', 26),
#              ('breezes', 26),
#              ('which', 572),
#              ('few', 104),
#              ('hours', 130),
#              ('previous', 104),
#              ('were', 962),
#              ('out', 956),
#              ('sight', 104),
#              ('land', 208),
#              ('look', 156),
#              ('at', 2184),
#              ('crowds', 52),
#              ('water', 234),
#              ('gazers', 26),
#              ('circumambulate', 26),
#              ('dreamy', 26),
#              ('sabbath', 52),
#              ('afternoon', 52),
#              ('go', 494),
#              ('corlears', 26),
#              ('hook', 26),
#              ('coenties', 26),
#              ('slip', 26),
#              ('thence', 52),
#              ('whitehall', 26),
#              ('northward', 26),
#              ('what', 1118),
#              ('do', 702),
#              ('see?--posted', 26),
#              ('like', 732),
#              ('silent', 52),
#              ('sentinels', 26),
#              ('around', 78),
#              ('town', 156),
#              ('stand', 182),
#              ('thousands', 52),
#              ('mortal', 26),
#              ('fixed', 78),
#              ('reveries', 52),
#              ('leaning', 52),
#              ('against', 234),
#              ('spiles', 26),
#              ('seated', 52),
#              ('pier', 26),
#              ('heads', 338),
#              ('looking', 312),
#              ('over', 702),
#              ('bulwarks', 52),
#              ('ships', 78),
#              ('china', 26),
#              ('aloft', 52),
#              ('rigging', 26),
#              ('striving', 26),
#              ('still', 364),
#              ('better', 208),
#              ('seaward', 26),
#              ('peep', 26),
#              ('these', 494),
#              ('are', 416),
#              ('landsmen', 26),
#              ('week', 52),
#              ('days', 104),
#              ('pent', 26),
#              ('lath', 26),
#              ('plaster', 52),
#              ('tied', 26),
#              ('counters', 26),
#              ('nailed', 26),
#              ('benches', 26),
#              ('clinched', 26),
#              ('desks', 26),
#              ('green', 130),
#              ('fields', 26),
#              ('gone', 52),
#              ('here', 598),
#              ('come', 338),
#              ('more', 494),
#              ('pacing', 26),
#              ('straight', 104),
#              ('seemingly', 26),
#              ('bound', 52),
#              ('dive', 26),
#              ('strange', 182),
#              ('will', 260),
#              ('content', 52),
#              ('them', 442),
#              ('extremest', 26),
#              ('limit', 26),
#              ('loitering', 26),
#              ('under', 260),
#              ('shady', 26),
#              ('lee', 26),
#              ('yonder', 52),
#              ('not', 1534),
#              ('suffice', 26),
#              ('must', 442),
#              ('just', 390),
#              ('nigh', 104),
#              ('possibly', 26),
#              ('without', 182),
#              ('falling', 52),
#              ('miles', 78),
#              ('leagues', 26),
#              ('inlanders', 26),
#              ('lanes', 26),
#              ('alleys', 26),
#              ('avenues', 26),
#              ('north', 52),
#              ('east', 26),
#              ('south', 156),
#              ('west', 26),
#              ('yet', 416),
#              ('unite', 26),
#              ('tell', 442),
#              ('does', 156),
#              ('magnetic', 26),
#              ('virtue', 26),
#              ('needles', 26),
#              ('compasses', 26),
#              ('those', 234),
#              ('attract', 26),
#              ('thither', 26),
#              ('once', 208),
#              ('say', 286),
#              ('country', 78),
#              ('lakes', 26),
#              ('any', 364),
#              ('path', 26),
#              ('please', 52),
#              ('ten', 52),
#              ('one', 1300),
#              ('carries', 26),
#              ('down', 468),
#              ('dale', 26),
#              ('leaves', 52),
#              ('pool', 26),
#              ('stream', 78),
#              ('magic', 52),
#              ('let', 156),
#              ('most', 468),
#              ('absent', 26),
#              ('minded', 26),
#              ('be', 1716),
#              ('plunged', 52),
#              ('deepest', 26),
#              ('man', 572),
#              ('legs', 104),
#              ('set', 156),
#              ('feet', 182),
#              ('going', 260),
#              ('he', 3247),
#              ('infallibly', 26),
#              ('lead', 78),
#              ('region', 26),
#              ('should', 286),
#              ('ever', 338),
#              ('athirst', 26),
#              ('great', 376),
#              ('american', 78),
#              ('desert', 26),
#              ('try', 104),
#              ('experiment', 26),
#              ('caravan', 26),
#              ('happen', 26),
#              ('supplied', 26),
#              ('metaphysical', 52),
#              ('professor', 26),
#              ('yes', 104),
#              ('knows', 26),
#              ('meditation', 26),
#              ('wedded', 26),
#              ('artist', 78),
#              ('desires', 26),
#              ('paint', 26),
#              ('dreamiest', 26),
#              ('shadiest', 26),
#              ('quietest', 26),
#              ('enchanting', 26),
#              ('bit', 130),
#              ('romantic', 26),
#              ('landscape', 26),
#              ('valley', 26),
#              ('saco', 26),
#              ('chief', 52),
#              ('element', 26),
#              ('employs', 26),
#              ('trees', 26),
#              ('each', 78),
#              ('hollow', 26),
#              ('trunk', 52),
#              ('hermit', 26),
#              ('crucifix', 26),
#              ('within', 130),
#              ('sleeps', 26),
#              ('meadow', 52),
#              ('sleep', 416),
#              ('cattle', 26),
#              ('cottage', 26),
#              ('goes', 78),
#              ('sleepy', 26),
#              ('smoke', 52),
#              ('deep', 78),
#              ('distant', 78),
#              ('woodlands', 26),
#              ('winds', 78),
#              ('mazy', 26),
#              ('reaching', 52),
#              ('overlapping', 26),
#              ('spurs', 26),
#              ('mountains', 26),
#              ('bathed', 26),
#              ('hill', 52),
#              ('side', 286),
#              ('blue', 78),
#              ('though', 494),
#              ('picture', 130),
#              ('lies', 26),
#              ('thus', 52),
#              ('tranced', 26),
#              ('pine', 52),
#              ('tree', 26),
#              ('shakes', 26),
#              ('sighs', 52),
#              ('shepherd', 52),
#              ('head', 598),
#              ('vain', 26),
#              ('unless', 104),
#              ('eye', 26),
#              ('him', 1092),
#              ('visit', 26),
#              ('prairies', 26),
#              ('june', 52),
#              ('when', 650),
#              ('scores', 52),
#              ('wade', 26),
#              ('knee', 26),
#              ('among', 78),
#              ('tiger', 26),
#              ('lilies', 26),
#              ('charm', 26),
#              ('wanting?--water', 26),
#              ('drop', 26),
#              ('niagara', 26),
#              ('cataract', 26),
#              ('sand', 26),
#              ('travel', 26),
#              ('thousand', 52),
#              ('why', 286),
#              ('did', 572),
#              ('poor', 104),
#              ('poet', 26),
#              ('tennessee', 26),
#              ('suddenly', 78),
#              ('receiving', 26),
#              ('two', 338),
#              ('handfuls', 26),
#              ('silver', 26),
#              ('deliberate', 26),
#              ('whether', 182),
#              ('buy', 26),
#              ('coat', 104),
#              ('sadly', 52),
#              ('needed', 26),
#              ('invest', 26),
#              ('pedestrian', 26),
#              ('trip', 26),
#              ('rockaway', 26),
#              ('beach', 26),
#              ('robust', 52),
#              ('healthy', 52),
#              ('boy', 52),
#              ('crazy', 52),
#              ('first', 494),
#              ('voyage', 208),
#              ('passenger', 104),
#              ('yourself', 156),
#              ('feel', 78),
#              ('mystical', 26),
#              ('vibration', 26),
#              ('told', 130),
#              ('old', 754),
#              ('persians', 26),
#              ('hold', 52),
#              ('holy', 52),
#              ('greeks', 26),
#              ('give', 208),
#              ('separate', 26),
#              ('deity', 26),
#              ('own', 286),
#              ('brother', 52),
#              ('jove', 26),
#              ('surely', 26),
#              ('meaning', 78),
#              ('deeper', 26),
#              ('story', 130),
#              ('narcissus', 26),
#              ('who', 416),
#              ('because', 182),
#              ('could', 650),
#              ('grasp', 26),
#              ('tormenting', 26),
#              ('mild', 26),
#              ('image', 156),
#              ('saw', 156),
#              ('fountain', 26),
#              ('was', 2886),
#              ('drowned', 26),
#              ('we', 286),
#              ('ourselves', 52),
#              ('rivers', 26),
#              ('oceans', 26),
#              ('ungraspable', 26),
#              ('phantom', 78),
#              ('life', 78),
#              ('key', 26),
#              ('am', 156),
#              ('habit', 26),
#              ('begin', 52),
#              ('grow', 52),
#              ('hazy', 26),
#              ('eyes', 182),
#              ('conscious', 26),
#              ('lungs', 26),
#              ('mean', 130),
#              ('inferred', 52),
#              ('needs', 52),
#              ('rag', 26),
#              ('something', 312),
#              ('besides', 156),
#              ('passengers', 78),
#              ('sick', 26),
#              ('quarrelsome', 26),
#              ("don't", 52),
#              ('nights', 26),
#              ('enjoy', 26),
#              ('themselves', 52),
#              ('much', 442),
#              ('general', 26),
#              ('thing;--no', 26),
#              ('nor', 78),
#              ('salt', 26),
#              ('commodore', 52),
#              ('captain', 52),
#              ('cook', 52),
#              ('abandon', 26),
#              ('glory', 52),
#              ('distinction', 26),
#              ('offices', 26),
#              ('abominate', 26),
#              ('honourable', 26),
#              ('respectable', 26),
#              ('toils', 26),
#              ('trials', 26),
#              ('tribulations', 26),
#              ('kind', 78),
#              ('whatsoever', 52),
#              ('quite', 78),
#              ('care', 78),
#              ('taking', 104),
#              ('barques', 26),
#              ('brigs', 26),
#              ('schooners', 26),
#              ('cook,--though', 26),
#              ('confess', 52),
#              ('considerable', 26),
#              ('being', 390),
#              ('sort', 494),
#              ('officer', 52),
#              ('board', 78),
#              ('somehow', 78),
#              ('fancied', 26),
#              ('broiling', 26),
#              ('fowls;--though', 26),
#              ('broiled', 78),
#              ('judiciously', 26),
#              ('buttered', 26),
#              ('judgmatically', 26),
#              ('salted', 26),
#              ('peppered', 26),
#              ('speak', 130),
#              ('respectfully', 52),
#              ('reverentially', 26),
#              ('fowl', 26),
#              ('than', 390),
#              ('idolatrous', 26),
#              ('dotings', 26),
#              ('egyptians', 26),
#              ('ibis', 26),
#              ('roasted', 26),
#              ('river', 26),
#              ('horse', 52),
#              ('mummies', 26),
#              ('creatures', 26),
#              ('huge', 52),
#              ('bake', 26),
#              ('houses', 52),
#              ('pyramids', 26),
#              ('simple', 26),
#              ('sailor', 156),
#              ('mast', 78),
#              ('plumb', 26),
#              ('forecastle', 52),
#              ('royal', 26),
#              ('true', 104),
#              ('rather', 208),
#              ('order', 130),
#              ('make', 260),
#              ('jump', 52),
#              ('spar', 52),
#              ('grasshopper', 26),
#              ('may', 312),
#              ('thing', 104),
#              ('unpleasant', 26),
#              ('enough', 338),
#              ('touches', 26),
#              ('sense', 78),
#              ('honour', 26),
#              ('particularly', 52),
#              ('established', 26),
#              ('family', 26),
#              ('van', 26),
#              ('rensselaers', 26),
#              ('randolphs', 26),
#              ('hardicanutes', 26),
#              ('putting', 52),
#              ('tar', 52),
#              ('pot', 26),
#              ('been', 468),
#              ('lording', 26),
#              ('schoolmaster', 52),
#              ('making', 130),
#              ('tallest', 26),
#              ('boys', 52),
#              ('awe', 26),
#              ('transition', 52),
#              ('keen', 26),
#              ('assure', 26),
#              ('decoction', 26),
#              ('seneca', 26),
#              ('stoics', 26),
#              ('enable', 26),
#              ('grin', 52),
#              ('bear', 52),
#              ('even', 130),
#              ('wears', 26),
#              ('hunks', 52),
#              ('orders', 26),
#              ('broom', 26),
#              ('sweep', 52),
#              ('decks', 26),
#              ('indignity', 26),
#              ('amount', 26),
#              ('weighed', 52),
#              ('scales', 26),
#              ('new', 286),
#              ('testament', 26),
#              ('think', 182),
#              ('archangel', 26),
#              ('gabriel', 26),
#              ('thinks', 182),
#              ('anything', 52),
#              ('less', 52),
#              ('promptly', 26),
#              ('obey', 26),
#              ('instance', 26),
#              ('ai', 104),
#              ("n't", 624),
#              ('slave', 26),
#              ('well', 208),
#              ('however', 208),
#              ('captains', 26),
#              ('thump', 52),
#              ('punch', 26),
#              ('satisfaction', 26),
#              ('knowing', 78),
#              ('everybody', 26),
#              ('else', 208),
#              ('served', 26),
#              ('either', 78),
#              ('physical', 26),
#              ('point', 52),
#              ('view', 52),
#              ('so', 1066),
#              ('universal', 26),
#              ('passed', 78),
#              ('hands', 78),
#              ('rub', 26),
#              ('shoulder', 26),
#              ('blades', 26),
#              ('again', 286),
#              ('always', 104),
#              ('paying', 78),
#              ('trouble', 26),
#              ('whereas', 26),
#              ('pay', 78),
#              ('single', 52),
#              ('penny', 78),
#              ('heard', 208),
#              ('contrary', 26),
#              ('difference', 52),
#              ('between', 234),
#              ('paid', 26),
#              ('act', 52),
#              ('perhaps', 130),
#              ('uncomfortable', 52),
#              ('infliction', 26),
#              ('orchard', 26),
#              ('thieves', 26),
#              ('entailed', 26),
#              ('us', 104),
#              ('paid,--what', 26),
#              ('compare', 52),
#              ('urbane', 26),
#              ('activity', 26),
#              ('receives', 26),
#              ('really', 104),
#              ('marvellous', 104),
#              ('considering', 26),
#              ('earnestly', 26),
#              ('believe', 26),
#              ('root', 26),
#              ('earthly', 52),
#              ('ills', 26),
#              ('monied', 26),
#              ('enter', 52),
#              ('heaven', 104),
#              ('ah', 26),
#              ('cheerfully', 26),
#              ('consign', 26),
#              ('perdition', 26),
#              ('finally', 26),
#              ('wholesome', 26),
#              ('exercise', 26),
#              ('pure', 26),
#              ('air', 104),
#              ('fore', 26),
#              ('castle', 26),
#              ('deck', 52),
#              ('far', 104),
#              ('prevalent', 26),
#              ('astern', 26),
#              ('violate', 26),
#              ('pythagorean', 26),
#              ('maxim', 26),
#              ('quarter', 52),
#              ('gets', 26),
#              ('atmosphere', 26),
#              ('second', 104),
#              ('sailors', 78),
#              ('breathes', 26),
#              ('commonalty', 26),
#              ('leaders', 52),
#              ('many', 104),
#              ('things', 130),
#              ('suspect', 26),
#              ('wherefore', 26),
#              ('after', 234),
#              ('repeatedly', 26),
#              ('smelt', 52),
#              ('merchant', 26),
#              ('whaling', 234),
#              ('invisible', 26),
#              ('police', 26),
#              ('fates', 52),
#              ('has', 104),
#              ('constant', 26),
#              ('surveillance', 26),
#              ('secretly', 26),
#              ('dogs', 26),
#              ('influences', 26),
#              ('unaccountable', 104),
#              ('answer', 130),
#              ('doubtless', 52),
#              ('formed', 52),
#              ('grand', 104),
#              ('programme', 26),
#              ('providence', 26),
#              ('drawn', 26),
#              ('came', 286),
#              ('brief', 26),
#              ('interlude', 26),
#              ('solo', 26),
#              ('extensive', 26),
#              ('performances', 26),
#              ('bill', 26),
#              ('run', 52),
#              ('contested', 26),
#              ('election', 26),
#              ('presidency', 26),
#              ('united', 26),
#              ('states', 26),
#              ('bloody', 26),
#              ('battle', 26),
#              ('affghanistan', 26),
#              ('exactly', 78),
#              ('stage', 52),
#              ('managers', 26),
#              ('put', 208),
#              ('shabby', 52),
#              ('others', 52),
#              ('magnificent', 26),
#              ('parts', 130),
#              ('tragedies', 26),
#              ('short', 78),
#              ('easy', 78),
#              ('genteel', 26),
#              ('comedies', 26),
#              ('jolly', 104),
#              ('farces', 26),
#              ('recall', 26),
#              ('circumstances', 52),
#              ('springs', 26),
#              ('motives', 52),
#              ('cunningly', 26),
#              ('presented', 26),
#              ('various', 52),
#              ('disguises', 26),
#              ('induced', 26),
#              ('performing', 26),
#              ('cajoling', 26),
#              ('delusion', 26),
#              ('choice', 26),
#              ('resulting', 26),
#              ('unbiased', 26),
#              ('freewill', 26),
#              ('discriminating', 26),
#              ('judgment', 26),
#              ('overwhelming', 26),
#              ('idea', 182),
#              ('whale', 260),
#              ('portentous', 78),
#              ('mysterious', 52),
#              ('monster', 26),
#              ('roused', 26),
#              ('curiosity', 52),
#              ('wild', 130),
#              ('seas', 156),
#              ('rolled', 156),
#              ('island', 78),
#              ('bulk', 26),
#              ('undeliverable', 26),
#              ('nameless', 78),
#              ('perils', 26),
#              ('attending', 26),
#              ('marvels', 26),
#              ('patagonian', 26),
#              ('sights', 26),
#              ('sounds', 78),
#              ('helped', 26),
#              ('sway', 26),
#              ('wish', 26),
#              ('inducements', 26),
#              ('tormented', 52),
#              ('everlasting', 52),
#              ('itch', 26),
#              ('remote', 26),
#              ('love', 26),
#              ('forbidden', 26),
#              ('barbarous', 26),
#              ('coasts', 26),
#              ('ignoring', 26),
#              ('good', 442),
#              ('quick', 26),
#              ('perceive', 26),
#              ('horror', 26),
#              ('social', 26),
#              ('since', 78),
#              ('friendly', 26),
#              ('terms', 26),
#              ('inmates', 26),
#              ('place', 390),
#              ('lodges', 26),
#              ('reason', 130),
#              ('welcome', 26),
#              ('flood', 26),
#              ('gates', 26),
#              ('wonder', 52),
#              ('swung', 26),
#              ('open', 104),
#              ('conceits', 26),
#              ('swayed', 26),
#              ('purpose', 52),
#              ('floated', 52),
#              ('inmost', 26),
#              ('endless', 26),
#              ('processions', 26),
#              ('mid', 26),
#              ('hooded', 26),
#              ('snow', 78),
#              ('stuffed', 52),
#              ('shirt', 104),
#              ('carpet', 26),
#              ('bag', 182),
#              ('tucked', 26),
#              ('arm', 286),
#              ('started', 26),
#              ('cape', 104),
#              ('horn', 52),
#              ('pacific', 26),
#              ('quitting', 26),
#              ('manhatto', 26),
#              ('duly', 26),
#              ('arrived', 52),
#              ('bedford', 104),
#              ('saturday', 78),
#              ('night', 624),
#              ('december', 26),
#              ('disappointed', 26),
#              ('learning', 26),
#              ('packet', 26),
#              ('nantucket', 182),
#              ('had', 858),
#              ('already', 26),
#              ('sailed', 26),
#              ('offer', 52),
#              ('till', 156),
#              ('following', 52),
#              ('monday', 26),
#              ('young', 130),
#              ('candidates', 26),
#              ('pains', 26),
#              ('penalties', 26),
#              ('stop', 208),
#              ('embark', 52),
#              ('related', 26),
#              ('doing', 26),
#              ('made', 338),
#              ('craft', 130),
#              ('fine', 104),
#              ('boisterous', 26),
#              ('everything', 26),
#              ('connected', 26),
#              ('famous', 26),
#              ('amazingly', 26),
#              ('pleased', 52),
#              ('late', 182),
#              ('gradually', 26),
#              ('monopolising', 26),
#              ('business', 130),
#              ('matter', 78),
#              ('behind', 26),
#              ('original', 52),
#              ('tyre', 26),
#              ('carthage;--the', 26),
#              ('dead', 130),
#              ('stranded', 52),
#              ('aboriginal', 26),
#              ('whalemen', 26),
#              ('red', 78),
#              ('sally', 26),
#              ('canoes', 26),
#              ('chase', 26),
#              ('leviathan', 52),
#              ('too', 364),
#              ('adventurous', 26),
#              ('sloop', 26),
#              ('forth', 26),
#              ('partly', 78),
#              ('laden', 26),
#              ('imported', 26),
#              ('cobblestones', 26),
#              ('throw', 26),
#              ('whales', 52),
#              ('discover', 26),
#              ('risk', 26),
#              ('harpoon', 135),
#              ('bowsprit', 26),
#              ('day', 156),
#              ('another', 130),
#              ('ere', 78),
#              ('destined', 26),
#              ('port', 26),
#              ('became', 78),
#              ('concernment', 26),
#              ('eat', 26),
#              ('meanwhile', 78),
#              ('dubious', 26),
#              ('nay', 52),
#              ('dark', 208),
#              ('dismal', 52),
#              ('bitingly', 26),
#              ('cold', 182),
#              ('cheerless', 26),
#              ('anxious', 26),
#              ('grapnels', 26),
#              ('sounded', 26),
#              ('pocket', 78),
#              ('only', 364),
#              ('brought', 26),
#              ('pieces', 26),
#              ('silver,--so', 26),
#              ('wherever', 52),
#              ('said', 494),
#              ('stood', 260),
#              ('middle', 130),
#              ('dreary', 52),
#              ('shouldering', 26),
#              ('comparing', 26),
#              ('gloom', 26),
#              ('darkness', 78),
#              ('wisdom', 26),
#              ('conclude', 26),
#              ('lodge', 26),
#              ('dear', 26),
#              ('sure', 130),
#              ('inquire', 26),
#              ('price', 26),
#              ('halting', 26),
#              ('steps', 26),
#              ('paced', 26),
#              ('sign', 156),
#              ('crossed', 52),
#              ('harpoons"--but', 26),
#              ('looked', 156),
#              ('expensive', 52),
#              ('further', 104),
#              ('bright', 52),
#              ('windows', 52),
#              ('fish', 78),
#              ('inn', 78),
#              ('fervent', 26),
#              ('rays', 26),
#              ('seemed', 416),
#              ('melted', 26),
#              ('packed', 52),
#              ('ice', 104),
#              ('house', 286),
#              ('everywhere', 26),
#              ('congealed', 26),
#              ('frost', 104),
#              ('lay', 234),
#              ('inches', 52),
#              ('thick', 52),
#              ...])

# %%
vocabulary_size = len(tokenizer.word_counts)

# %%
vocabulary_size
# Out:
# 2717

# %%
type(sequences)
# Out:
# list

# %% [markdown]
# Convert to Numpy Matrix

# %%
import numpy as np

# %%
sequences = np.array(sequences)

# %%
sequences[0]
# Out:
# array([ 956,   14,  263,   51,  261,  408,   87,  219,  129,  111,  954,
#         260,   50,   43,   38,  315,    7,   23,  546,    3,  150,  259,
#           6, 2712,   14,   24])

# %% [markdown]
# Train / Test Split

# %%
from keras.utils import to_categorical

# %%
#Get the sequence except last one
x = sequences[:,:-1]

# %%
#Get only last index value
y = sequences[:,-1]

# %%
#We will be having vocabulary number of unique values, so we can create that many number of categories
y = to_categorical(y,num_classes=vocabulary_size+1)

# %%
x.shape
# Out:
# (11312, 25)

# %%
seq_len = x.shape[1]

# %% [markdown]
# Creating an LSTM based model

# %%
from keras.models import  Sequential
from keras.layers import Dense,LSTM,Embedding

# %%
def create_model(vocabulary_size,seq_len):

  model = Sequential()

  model.add(Embedding(vocabulary_size,seq_len, input_length = seq_len))
  model.add(LSTM(50,return_sequences=True))
  model.add(LSTM(50))
  model.add(Dense(50,activation="relu"))
  model.add(Dense(vocabulary_size,activation="softmax"))

  model.compile(loss="categorical_crossentropy",optimizer="adam",metrics=["accuracy"])

  model.summary()

  return model

# %% [markdown]
# Training the Model

# %%
# define model
model = create_model(vocabulary_size+1,seq_len)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 25, 25)            67950
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 25, 50)            15200
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_3 (Dense)              (None, 2718)              138618
# =================================================================
# Total params: 244,518
# Trainable params: 244,518
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
model.fit(x,y,batch_size=128,epochs=200,verbose=1)
# Out:
# Epoch 1/200
# 89/89 [==============================] - 5s 58ms/step - loss: 6.9667 - accuracy: 0.0443
# Epoch 2/200
# 89/89 [==============================] - 5s 58ms/step - loss: 6.3767 - accuracy: 0.0529
# Epoch 3/200
# 89/89 [==============================] - 5s 58ms/step - loss: 6.3442 - accuracy: 0.0529
# Epoch 4/200
# 89/89 [==============================] - 5s 59ms/step - loss: 6.2840 - accuracy: 0.0529
# Epoch 5/200
# 89/89 [==============================] - 5s 58ms/step - loss: 6.1702 - accuracy: 0.0529
# Epoch 6/200
# 89/89 [==============================] - 5s 59ms/step - loss: 6.1041 - accuracy: 0.0529
# Epoch 7/200
# 89/89 [==============================] - 5s 59ms/step - loss: 6.0506 - accuracy: 0.0532
# Epoch 8/200
# 89/89 [==============================] - 5s 60ms/step - loss: 5.9646 - accuracy: 0.0609
# Epoch 9/200
# 89/89 [==============================] - 5s 60ms/step - loss: 5.8813 - accuracy: 0.0640
# Epoch 10/200
# 89/89 [==============================] - 5s 59ms/step - loss: 5.8104 - accuracy: 0.0673
# Epoch 11/200
# 89/89 [==============================] - 5s 61ms/step - loss: 5.7520 - accuracy: 0.0664
# Epoch 12/200
# 89/89 [==============================] - 6s 63ms/step - loss: 5.6954 - accuracy: 0.0688
# Epoch 13/200
# 89/89 [==============================] - 5s 58ms/step - loss: 5.6449 - accuracy: 0.0691
# Epoch 14/200
# 89/89 [==============================] - 5s 60ms/step - loss: 5.5970 - accuracy: 0.0726
# Epoch 15/200
# 89/89 [==============================] - 5s 59ms/step - loss: 5.5606 - accuracy: 0.0729
# Epoch 16/200
# 89/89 [==============================] - 5s 60ms/step - loss: 5.5260 - accuracy: 0.0747
# Epoch 17/200
# 89/89 [==============================] - 5s 59ms/step - loss: 5.4971 - accuracy: 0.0765
# Epoch 18/200
# 89/89 [==============================] - 5s 59ms/step - loss: 5.4626 - accuracy: 0.0791
# Epoch 19/200
# 89/89 [==============================] - 5s 59ms/step - loss: 5.4274 - accuracy: 0.0801
# Epoch 20/200
# 89/89 [==============================] - 5s 59ms/step - loss: 5.3890 - accuracy: 0.0805
# Epoch 21/200
# 89/89 [==============================] - 5s 59ms/step - loss: 5.3517 - accuracy: 0.0816
# Epoch 22/200
# 89/89 [==============================] - 5s 59ms/step - loss: 5.3148 - accuracy: 0.0813
# Epoch 23/200
# 89/89 [==============================] - 5s 59ms/step - loss: 5.2812 - accuracy: 0.0855
# Epoch 24/200
# 89/89 [==============================] - 5s 59ms/step - loss: 5.2491 - accuracy: 0.0872
# Epoch 25/200
# 89/89 [==============================] - 5s 59ms/step - loss: 5.2185 - accuracy: 0.0867
# Epoch 26/200
# 89/89 [==============================] - 5s 59ms/step - loss: 5.1879 - accuracy: 0.0896
# Epoch 27/200
# 89/89 [==============================] - 5s 58ms/step - loss: 5.1615 - accuracy: 0.0915
# Epoch 28/200
# 89/89 [==============================] - 5s 59ms/step - loss: 5.1323 - accuracy: 0.0922
# Epoch 29/200
# 89/89 [==============================] - 5s 59ms/step - loss: 5.1069 - accuracy: 0.0951
# Epoch 30/200
# 89/89 [==============================] - 5s 59ms/step - loss: 5.0786 - accuracy: 0.0959
# Epoch 31/200
# 89/89 [==============================] - 5s 59ms/step - loss: 5.0454 - accuracy: 0.0976
# Epoch 32/200
# 89/89 [==============================] - 5s 60ms/step - loss: 5.0121 - accuracy: 0.0991
# Epoch 33/200
# 89/89 [==============================] - 5s 60ms/step - loss: 4.9787 - accuracy: 0.1008
# Epoch 34/200
# 89/89 [==============================] - 5s 59ms/step - loss: 4.9426 - accuracy: 0.1034
# Epoch 35/200
# 89/89 [==============================] - 5s 59ms/step - loss: 4.9064 - accuracy: 0.1072
# Epoch 36/200
# 89/89 [==============================] - 5s 59ms/step - loss: 4.8666 - accuracy: 0.1082
# Epoch 37/200
# 89/89 [==============================] - 5s 59ms/step - loss: 4.8310 - accuracy: 0.1120
# Epoch 38/200
# 89/89 [==============================] - 5s 59ms/step - loss: 4.7918 - accuracy: 0.1162
# Epoch 39/200
# 89/89 [==============================] - 5s 59ms/step - loss: 4.7471 - accuracy: 0.1173
# Epoch 40/200
# 89/89 [==============================] - 5s 60ms/step - loss: 4.7049 - accuracy: 0.1216
# Epoch 41/200
# 89/89 [==============================] - 5s 59ms/step - loss: 4.6628 - accuracy: 0.1239
# Epoch 42/200
# 89/89 [==============================] - 5s 60ms/step - loss: 4.6180 - accuracy: 0.1314
# Epoch 43/200
# 89/89 [==============================] - 5s 60ms/step - loss: 4.5728 - accuracy: 0.1333
# Epoch 44/200
# 89/89 [==============================] - 5s 59ms/step - loss: 4.5313 - accuracy: 0.1393
# Epoch 45/200
# 89/89 [==============================] - 5s 58ms/step - loss: 4.4923 - accuracy: 0.1403
# Epoch 46/200
# 89/89 [==============================] - 5s 58ms/step - loss: 4.4466 - accuracy: 0.1436
# Epoch 47/200
# 89/89 [==============================] - 5s 59ms/step - loss: 4.4035 - accuracy: 0.1454
# Epoch 48/200
# 89/89 [==============================] - 5s 59ms/step - loss: 4.3709 - accuracy: 0.1490
# Epoch 49/200
# 89/89 [==============================] - 5s 59ms/step - loss: 4.3302 - accuracy: 0.1502
# Epoch 50/200
# 89/89 [==============================] - 5s 58ms/step - loss: 4.2899 - accuracy: 0.1560
# Epoch 51/200
# 89/89 [==============================] - 5s 59ms/step - loss: 4.2536 - accuracy: 0.1587
# Epoch 52/200
# 89/89 [==============================] - 5s 60ms/step - loss: 4.2198 - accuracy: 0.1611
# Epoch 53/200
# 89/89 [==============================] - 5s 60ms/step - loss: 4.1877 - accuracy: 0.1603
# Epoch 54/200
# 89/89 [==============================] - 5s 59ms/step - loss: 4.1480 - accuracy: 0.1665
# Epoch 55/200
# 89/89 [==============================] - 5s 60ms/step - loss: 4.1136 - accuracy: 0.1664
# Epoch 56/200
# 89/89 [==============================] - 6s 63ms/step - loss: 4.0809 - accuracy: 0.1709
# Epoch 57/200
# 89/89 [==============================] - 6s 62ms/step - loss: 4.0492 - accuracy: 0.1720
# Epoch 58/200
# 89/89 [==============================] - 6s 63ms/step - loss: 4.0158 - accuracy: 0.1774
# Epoch 59/200
# 89/89 [==============================] - 5s 61ms/step - loss: 3.9867 - accuracy: 0.1777
# Epoch 60/200
# 89/89 [==============================] - 5s 60ms/step - loss: 3.9544 - accuracy: 0.1803
# Epoch 61/200
# 89/89 [==============================] - 5s 59ms/step - loss: 3.9246 - accuracy: 0.1811
# Epoch 62/200
# 89/89 [==============================] - 5s 60ms/step - loss: 3.8964 - accuracy: 0.1826
# Epoch 63/200
# 89/89 [==============================] - 5s 60ms/step - loss: 3.8663 - accuracy: 0.1886
# Epoch 64/200
# 89/89 [==============================] - 5s 60ms/step - loss: 3.8373 - accuracy: 0.1904
# Epoch 65/200
# 89/89 [==============================] - 5s 59ms/step - loss: 3.8055 - accuracy: 0.1949
# Epoch 66/200
# 89/89 [==============================] - 5s 60ms/step - loss: 3.7737 - accuracy: 0.1962
# Epoch 67/200
# 89/89 [==============================] - 5s 59ms/step - loss: 3.7524 - accuracy: 0.2002
# Epoch 68/200
# 89/89 [==============================] - 5s 59ms/step - loss: 3.7140 - accuracy: 0.2056
# Epoch 69/200
# 89/89 [==============================] - 6s 63ms/step - loss: 3.6874 - accuracy: 0.2043
# Epoch 70/200
# 89/89 [==============================] - 5s 62ms/step - loss: 3.6637 - accuracy: 0.2063
# Epoch 71/200
# 89/89 [==============================] - 5s 60ms/step - loss: 3.6306 - accuracy: 0.2124
# Epoch 72/200
# 89/89 [==============================] - 5s 60ms/step - loss: 3.6129 - accuracy: 0.2135
# Epoch 73/200
# 89/89 [==============================] - 5s 59ms/step - loss: 3.5847 - accuracy: 0.2160
# Epoch 74/200
# 89/89 [==============================] - 5s 59ms/step - loss: 3.5567 - accuracy: 0.2222
# Epoch 75/200
# 89/89 [==============================] - 5s 60ms/step - loss: 3.5323 - accuracy: 0.2237
# Epoch 76/200
# 89/89 [==============================] - 5s 60ms/step - loss: 3.5105 - accuracy: 0.2257
# Epoch 77/200
# 89/89 [==============================] - 5s 60ms/step - loss: 3.4767 - accuracy: 0.2308
# Epoch 78/200
# 89/89 [==============================] - 5s 60ms/step - loss: 3.4492 - accuracy: 0.2365
# Epoch 79/200
# 89/89 [==============================] - 5s 59ms/step - loss: 3.4297 - accuracy: 0.2344
# Epoch 80/200
# 89/89 [==============================] - 5s 59ms/step - loss: 3.4012 - accuracy: 0.2468
# Epoch 81/200
# 89/89 [==============================] - 5s 60ms/step - loss: 3.3782 - accuracy: 0.2469
# Epoch 82/200
# 89/89 [==============================] - 5s 60ms/step - loss: 3.3541 - accuracy: 0.2511
# Epoch 83/200
# 89/89 [==============================] - 5s 60ms/step - loss: 3.3303 - accuracy: 0.2557
# Epoch 84/200
# 89/89 [==============================] - 5s 60ms/step - loss: 3.3092 - accuracy: 0.2598
# Epoch 85/200
# 89/89 [==============================] - 5s 60ms/step - loss: 3.2819 - accuracy: 0.2583
# Epoch 86/200
# 89/89 [==============================] - 5s 59ms/step - loss: 3.2558 - accuracy: 0.2706
# Epoch 87/200
# 89/89 [==============================] - 5s 61ms/step - loss: 3.2282 - accuracy: 0.2701
# Epoch 88/200
# 89/89 [==============================] - 5s 59ms/step - loss: 3.2222 - accuracy: 0.2700
# Epoch 89/200
# 89/89 [==============================] - 5s 60ms/step - loss: 3.1932 - accuracy: 0.2745
# Epoch 90/200
# 89/89 [==============================] - 5s 61ms/step - loss: 3.1730 - accuracy: 0.2796
# Epoch 91/200
# 89/89 [==============================] - 5s 61ms/step - loss: 3.1436 - accuracy: 0.2832
# Epoch 92/200
# 89/89 [==============================] - 5s 60ms/step - loss: 3.1220 - accuracy: 0.2842
# Epoch 93/200
# 89/89 [==============================] - 5s 59ms/step - loss: 3.0994 - accuracy: 0.2873
# Epoch 94/200
# 89/89 [==============================] - 5s 59ms/step - loss: 3.0836 - accuracy: 0.2931
# Epoch 95/200
# 89/89 [==============================] - 5s 59ms/step - loss: 3.0618 - accuracy: 0.2988
# Epoch 96/200
# 89/89 [==============================] - 5s 60ms/step - loss: 3.0403 - accuracy: 0.2998
# Epoch 97/200
# 89/89 [==============================] - 5s 60ms/step - loss: 3.0197 - accuracy: 0.3023
# Epoch 98/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.9935 - accuracy: 0.3106
# Epoch 99/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.9703 - accuracy: 0.3156
# Epoch 100/200
# 89/89 [==============================] - 5s 59ms/step - loss: 2.9576 - accuracy: 0.3184
# Epoch 101/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.9299 - accuracy: 0.3202
# Epoch 102/200
# 89/89 [==============================] - 5s 59ms/step - loss: 2.9107 - accuracy: 0.3226
# Epoch 103/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.8837 - accuracy: 0.3289
# Epoch 104/200
# 89/89 [==============================] - 5s 61ms/step - loss: 2.8779 - accuracy: 0.3279
# Epoch 105/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.8556 - accuracy: 0.3335
# Epoch 106/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.8360 - accuracy: 0.3358
# Epoch 107/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.8062 - accuracy: 0.3441
# Epoch 108/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.8056 - accuracy: 0.3441
# Epoch 109/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.7755 - accuracy: 0.3456
# Epoch 110/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.7577 - accuracy: 0.3554
# Epoch 111/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.7426 - accuracy: 0.3556
# Epoch 112/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.7249 - accuracy: 0.3566
# Epoch 113/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.6986 - accuracy: 0.3624
# Epoch 114/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.6759 - accuracy: 0.3674
# Epoch 115/200
# 89/89 [==============================] - 6s 63ms/step - loss: 2.6590 - accuracy: 0.3724
# Epoch 116/200
# 89/89 [==============================] - 6s 63ms/step - loss: 2.6455 - accuracy: 0.3757
# Epoch 117/200
# 89/89 [==============================] - 6s 63ms/step - loss: 2.6287 - accuracy: 0.3807
# Epoch 118/200
# 89/89 [==============================] - 6s 64ms/step - loss: 2.6088 - accuracy: 0.3832
# Epoch 119/200
# 89/89 [==============================] - 5s 62ms/step - loss: 2.6059 - accuracy: 0.3812
# Epoch 120/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.5917 - accuracy: 0.3888
# Epoch 121/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.5747 - accuracy: 0.3904
# Epoch 122/200
# 89/89 [==============================] - 5s 61ms/step - loss: 2.5477 - accuracy: 0.3962
# Epoch 123/200
# 89/89 [==============================] - 5s 61ms/step - loss: 2.5230 - accuracy: 0.3984
# Epoch 124/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.5058 - accuracy: 0.4028
# Epoch 125/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.4905 - accuracy: 0.4068
# Epoch 126/200
# 89/89 [==============================] - 6s 66ms/step - loss: 2.4671 - accuracy: 0.4148
# Epoch 127/200
# 89/89 [==============================] - 5s 61ms/step - loss: 2.4646 - accuracy: 0.4099
# Epoch 128/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.4555 - accuracy: 0.4130
# Epoch 129/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.4391 - accuracy: 0.4164
# Epoch 130/200
# 89/89 [==============================] - 5s 59ms/step - loss: 2.4149 - accuracy: 0.4218
# Epoch 131/200
# 89/89 [==============================] - 5s 61ms/step - loss: 2.3988 - accuracy: 0.4257
# Epoch 132/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.3796 - accuracy: 0.4303
# Epoch 133/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.3604 - accuracy: 0.4328
# Epoch 134/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.3543 - accuracy: 0.4386
# Epoch 135/200
# 89/89 [==============================] - 5s 61ms/step - loss: 2.3404 - accuracy: 0.4381
# Epoch 136/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.3184 - accuracy: 0.4421
# Epoch 137/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.3093 - accuracy: 0.4434
# Epoch 138/200
# 89/89 [==============================] - 5s 61ms/step - loss: 2.3010 - accuracy: 0.4488
# Epoch 139/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.2934 - accuracy: 0.4470
# Epoch 140/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.2727 - accuracy: 0.4509
# Epoch 141/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.2573 - accuracy: 0.4562
# Epoch 142/200
# 89/89 [==============================] - 5s 61ms/step - loss: 2.2370 - accuracy: 0.4609
# Epoch 143/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.2266 - accuracy: 0.4646
# Epoch 144/200
# 89/89 [==============================] - 5s 61ms/step - loss: 2.2142 - accuracy: 0.4649
# Epoch 145/200
# 89/89 [==============================] - 5s 61ms/step - loss: 2.1999 - accuracy: 0.4714
# Epoch 146/200
# 89/89 [==============================] - 5s 61ms/step - loss: 2.1875 - accuracy: 0.4693
# Epoch 147/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.1831 - accuracy: 0.4668
# Epoch 148/200
# 89/89 [==============================] - 5s 59ms/step - loss: 2.1598 - accuracy: 0.4777
# Epoch 149/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.1372 - accuracy: 0.4815
# Epoch 150/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.1279 - accuracy: 0.4839
# Epoch 151/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.1217 - accuracy: 0.4874
# Epoch 152/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.1229 - accuracy: 0.4813
# Epoch 153/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.1055 - accuracy: 0.4855
# Epoch 154/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.0819 - accuracy: 0.4928
# Epoch 155/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.0646 - accuracy: 0.4948
# Epoch 156/200
# 89/89 [==============================] - 5s 59ms/step - loss: 2.0512 - accuracy: 0.4986
# Epoch 157/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.0288 - accuracy: 0.5022
# Epoch 158/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.0307 - accuracy: 0.5050
# Epoch 159/200
# 89/89 [==============================] - 5s 61ms/step - loss: 2.0104 - accuracy: 0.5073
# Epoch 160/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.0125 - accuracy: 0.5072
# Epoch 161/200
# 89/89 [==============================] - 5s 60ms/step - loss: 2.0053 - accuracy: 0.5094
# Epoch 162/200
# 89/89 [==============================] - 5s 61ms/step - loss: 2.0033 - accuracy: 0.5074
# Epoch 163/200
# 89/89 [==============================] - 5s 60ms/step - loss: 1.9768 - accuracy: 0.5101
# Epoch 164/200
# 89/89 [==============================] - 5s 61ms/step - loss: 1.9539 - accuracy: 0.5204
# Epoch 165/200
# 89/89 [==============================] - 5s 60ms/step - loss: 1.9372 - accuracy: 0.5271
# Epoch 166/200
# 89/89 [==============================] - 5s 60ms/step - loss: 1.9224 - accuracy: 0.5268
# Epoch 167/200
# 89/89 [==============================] - 5s 61ms/step - loss: 1.9111 - accuracy: 0.5338
# Epoch 168/200
# 89/89 [==============================] - 5s 60ms/step - loss: 1.8938 - accuracy: 0.5332
# Epoch 169/200
# 89/89 [==============================] - 5s 60ms/step - loss: 1.8913 - accuracy: 0.5348
# Epoch 170/200
# 89/89 [==============================] - 5s 61ms/step - loss: 1.8864 - accuracy: 0.5336
# Epoch 171/200
# 89/89 [==============================] - 5s 61ms/step - loss: 1.8736 - accuracy: 0.5406
# Epoch 172/200
# 89/89 [==============================] - 5s 60ms/step - loss: 1.8547 - accuracy: 0.5416
# Epoch 173/200
# 89/89 [==============================] - 5s 61ms/step - loss: 1.8366 - accuracy: 0.5498
# Epoch 174/200
# 89/89 [==============================] - 5s 60ms/step - loss: 1.8272 - accuracy: 0.5484
# Epoch 175/200
# 89/89 [==============================] - 6s 65ms/step - loss: 1.8093 - accuracy: 0.5525
# Epoch 176/200
# 89/89 [==============================] - 6s 65ms/step - loss: 1.8268 - accuracy: 0.5505
# Epoch 177/200
# 89/89 [==============================] - 5s 60ms/step - loss: 1.7927 - accuracy: 0.5549
# Epoch 178/200
# 89/89 [==============================] - 5s 60ms/step - loss: 1.7697 - accuracy: 0.5605
# Epoch 179/200
# 89/89 [==============================] - 5s 59ms/step - loss: 1.7581 - accuracy: 0.5657
# Epoch 180/200
# 89/89 [==============================] - 5s 60ms/step - loss: 1.7535 - accuracy: 0.5623
# Epoch 181/200
# 89/89 [==============================] - 5s 60ms/step - loss: 1.7358 - accuracy: 0.5690
# Epoch 182/200
# 89/89 [==============================] - 5s 62ms/step - loss: 1.7335 - accuracy: 0.5694
# Epoch 183/200
# 89/89 [==============================] - 6s 64ms/step - loss: 1.7284 - accuracy: 0.5724
# Epoch 184/200
# 89/89 [==============================] - 5s 61ms/step - loss: 1.7118 - accuracy: 0.5730
# Epoch 185/200
# 89/89 [==============================] - 5s 60ms/step - loss: 1.7060 - accuracy: 0.5782
# Epoch 186/200
# 89/89 [==============================] - 5s 60ms/step - loss: 1.6869 - accuracy: 0.5781
# Epoch 187/200
# 89/89 [==============================] - 5s 61ms/step - loss: 1.6823 - accuracy: 0.5806
# Epoch 188/200
# 89/89 [==============================] - 5s 61ms/step - loss: 1.6714 - accuracy: 0.5827
# Epoch 189/200
# 89/89 [==============================] - 5s 60ms/step - loss: 1.6594 - accuracy: 0.5888
# Epoch 190/200
# 89/89 [==============================] - 5s 61ms/step - loss: 1.6338 - accuracy: 0.5931
# Epoch 191/200
# 89/89 [==============================] - 5s 60ms/step - loss: 1.6227 - accuracy: 0.5946
# Epoch 192/200
# 89/89 [==============================] - 5s 61ms/step - loss: 1.6028 - accuracy: 0.6057
# Epoch 193/200
# 89/89 [==============================] - 5s 60ms/step - loss: 1.6100 - accuracy: 0.5993
# Epoch 194/200
# 89/89 [==============================] - 5s 60ms/step - loss: 1.6085 - accuracy: 0.5965
# Epoch 195/200
# 89/89 [==============================] - 5s 60ms/step - loss: 1.5964 - accuracy: 0.6009
# Epoch 196/200
# 89/89 [==============================] - 5s 59ms/step - loss: 1.5735 - accuracy: 0.6106
# Epoch 197/200
# 89/89 [==============================] - 5s 59ms/step - loss: 1.5902 - accuracy: 0.6012
# Epoch 198/200
# 89/89 [==============================] - 5s 60ms/step - loss: 1.5628 - accuracy: 0.6087
# Epoch 199/200
# 89/89 [==============================] - 5s 60ms/step - loss: 1.5606 - accuracy: 0.6109
# Epoch 200/200
# 89/89 [==============================] - 5s 59ms/step - loss: 1.5817 - accuracy: 0.6021

# %% [markdown]
# **Generating New Text**

# %%
from keras.preprocessing.sequence import pad_sequences

# %%
def generate_text(model,tokenizer,seq_len,seed_text,num_gen_words):

  # Final Output
  output_text = []

  # Intial Seed Sequence
  input_text = seed_text

  # Create num_gen_words
  for i in range(num_gen_words):

    # Take the input text string and encode it to a sequence
    encoded_text = tokenizer.texts_to_sequences([input_text])[0]

    # Pad sequences to our trained rate (25 words in the video)
    pad_encoded = pad_sequences([encoded_text],maxlen=seq_len,truncating="pre")

    # Predict Class Probabilities for each word
    pre_word_ind = model.predict_classes(pad_encoded,verbose=0)[0]

    # Grab word
    pred_word = tokenizer.index_word[pre_word_ind]
    
     # Update the sequence of input text (shifting one over with the new word)
    input_text += " " + pred_word

    output_text.append(pred_word)

   # Make it look like a sentence.
  return " ".join(output_text)

# %%
text_sequences
# Out:
# [['call',
#   'me',
#   'ishmael',
#   'some',
#   'years',
#   'ago',
#   'never',
#   'mind',
#   'how',
#   'long',
#   'precisely',
#   'having',
#   'little',
#   'or',
#   'no',
#   'money',
#   'in',
#   'my',
#   'purse',
#   'and',
#   'nothing',
#   'particular',
#   'to',
#   'interest',
#   'me',
#   'on'],
#  ['me',
#   'ishmael',
#   'some',
#   'years',
#   'ago',
#   'never',
#   'mind',
#   'how',
#   'long',
#   'precisely',
#   'having',
#   'little',
#   'or',
#   'no',
#   'money',
#   'in',
#   'my',
#   'purse',
#   'and',
#   'nothing',
#   'particular',
#   'to',
#   'interest',
#   'me',
#   'on',
#   'shore'],
#  ['ishmael',
#   'some',
#   'years',
#   'ago',
#   'never',
#   'mind',
#   'how',
#   'long',
#   'precisely',
#   'having',
#   'little',
#   'or',
#   'no',
#   'money',
#   'in',
#   'my',
#   'purse',
#   'and',
#   'nothing',
#   'particular',
#   'to',
#   'interest',
#   'me',
#   'on',
#   'shore',
#   'i'],
#  ['some',
#   'years',
#   'ago',
#   'never',
#   'mind',
#   'how',
#   'long',
#   'precisely',
#   'having',
#   'little',
#   'or',
#   'no',
#   'money',
#   'in',
#   'my',
#   'purse',
#   'and',
#   'nothing',
#   'particular',
#   'to',
#   'interest',
#   'me',
#   'on',
#   'shore',
#   'i',
#   'thought'],
#  ['years',
#   'ago',
#   'never',
#   'mind',
#   'how',
#   'long',
#   'precisely',
#   'having',
#   'little',
#   'or',
#   'no',
#   'money',
#   'in',
#   'my',
#   'purse',
#   'and',
#   'nothing',
#   'particular',
#   'to',
#   'interest',
#   'me',
#   'on',
#   'shore',
#   'i',
#   'thought',
#   'i'],
#  ['ago',
#   'never',
#   'mind',
#   'how',
#   'long',
#   'precisely',
#   'having',
#   'little',
#   'or',
#   'no',
#   'money',
#   'in',
#   'my',
#   'purse',
#   'and',
#   'nothing',
#   'particular',
#   'to',
#   'interest',
#   'me',
#   'on',
#   'shore',
#   'i',
#   'thought',
#   'i',
#   'would'],
#  ['never',
#   'mind',
#   'how',
#   'long',
#   'precisely',
#   'having',
#   'little',
#   'or',
#   'no',
#   'money',
#   'in',
#   'my',
#   'purse',
#   'and',
#   'nothing',
#   'particular',
#   'to',
#   'interest',
#   'me',
#   'on',
#   'shore',
#   'i',
#   'thought',
#   'i',
#   'would',
#   'sail'],
#  ['mind',
#   'how',
#   'long',
#   'precisely',
#   'having',
#   'little',
#   'or',
#   'no',
#   'money',
#   'in',
#   'my',
#   'purse',
#   'and',
#   'nothing',
#   'particular',
#   'to',
#   'interest',
#   'me',
#   'on',
#   'shore',
#   'i',
#   'thought',
#   'i',
#   'would',
#   'sail',
#   'about'],
#  ['how',
#   'long',
#   'precisely',
#   'having',
#   'little',
#   'or',
#   'no',
#   'money',
#   'in',
#   'my',
#   'purse',
#   'and',
#   'nothing',
#   'particular',
#   'to',
#   'interest',
#   'me',
#   'on',
#   'shore',
#   'i',
#   'thought',
#   'i',
#   'would',
#   'sail',
#   'about',
#   'a'],
#  ['long',
#   'precisely',
#   'having',
#   'little',
#   'or',
#   'no',
#   'money',
#   'in',
#   'my',
#   'purse',
#   'and',
#   'nothing',
#   'particular',
#   'to',
#   'interest',
#   'me',
#   'on',
#   'shore',
#   'i',
#   'thought',
#   'i',
#   'would',
#   'sail',
#   'about',
#   'a',
#   'little'],
#  ['precisely',
#   'having',
#   'little',
#   'or',
#   'no',
#   'money',
#   'in',
#   'my',
#   'purse',
#   'and',
#   'nothing',
#   'particular',
#   'to',
#   'interest',
#   'me',
#   'on',
#   'shore',
#   'i',
#   'thought',
#   'i',
#   'would',
#   'sail',
#   'about',
#   'a',
#   'little',
#   'and'],
#  ['having',
#   'little',
#   'or',
#   'no',
#   'money',
#   'in',
#   'my',
#   'purse',
#   'and',
#   'nothing',
#   'particular',
#   'to',
#   'interest',
#   'me',
#   'on',
#   'shore',
#   'i',
#   'thought',
#   'i',
#   'would',
#   'sail',
#   'about',
#   'a',
#   'little',
#   'and',
#   'see'],
#  ['little',
#   'or',
#   'no',
#   'money',
#   'in',
#   'my',
#   'purse',
#   'and',
#   'nothing',
#   'particular',
#   'to',
#   'interest',
#   'me',
#   'on',
#   'shore',
#   'i',
#   'thought',
#   'i',
#   'would',
#   'sail',
#   'about',
#   'a',
#   'little',
#   'and',
#   'see',
#   'the'],
#  ['or',
#   'no',
#   'money',
#   'in',
#   'my',
#   'purse',
#   'and',
#   'nothing',
#   'particular',
#   'to',
#   'interest',
#   'me',
#   'on',
#   'shore',
#   'i',
#   'thought',
#   'i',
#   'would',
#   'sail',
#   'about',
#   'a',
#   'little',
#   'and',
#   'see',
#   'the',
#   'watery'],
#  ['no',
#   'money',
#   'in',
#   'my',
#   'purse',
#   'and',
#   'nothing',
#   'particular',
#   'to',
#   'interest',
#   'me',
#   'on',
#   'shore',
#   'i',
#   'thought',
#   'i',
#   'would',
#   'sail',
#   'about',
#   'a',
#   'little',
#   'and',
#   'see',
#   'the',
#   'watery',
#   'part'],
#  ['money',
#   'in',
#   'my',
#   'purse',
#   'and',
#   'nothing',
#   'particular',
#   'to',
#   'interest',
#   'me',
#   'on',
#   'shore',
#   'i',
#   'thought',
#   'i',
#   'would',
#   'sail',
#   'about',
#   'a',
#   'little',
#   'and',
#   'see',
#   'the',
#   'watery',
#   'part',
#   'of'],
#  ['in',
#   'my',
#   'purse',
#   'and',
#   'nothing',
#   'particular',
#   'to',
#   'interest',
#   'me',
#   'on',
#   'shore',
#   'i',
#   'thought',
#   'i',
#   'would',
#   'sail',
#   'about',
#   'a',
#   'little',
#   'and',
#   'see',
#   'the',
#   'watery',
#   'part',
#   'of',
#   'the'],
#  ['my',
#   'purse',
#   'and',
#   'nothing',
#   'particular',
#   'to',
#   'interest',
#   'me',
#   'on',
#   'shore',
#   'i',
#   'thought',
#   'i',
#   'would',
#   'sail',
#   'about',
#   'a',
#   'little',
#   'and',
#   'see',
#   'the',
#   'watery',
#   'part',
#   'of',
#   'the',
#   'world'],
#  ['purse',
#   'and',
#   'nothing',
#   'particular',
#   'to',
#   'interest',
#   'me',
#   'on',
#   'shore',
#   'i',
#   'thought',
#   'i',
#   'would',
#   'sail',
#   'about',
#   'a',
#   'little',
#   'and',
#   'see',
#   'the',
#   'watery',
#   'part',
#   'of',
#   'the',
#   'world',
#   'it'],
#  ['and',
#   'nothing',
#   'particular',
#   'to',
#   'interest',
#   'me',
#   'on',
#   'shore',
#   'i',
#   'thought',
#   'i',
#   'would',
#   'sail',
#   'about',
#   'a',
#   'little',
#   'and',
#   'see',
#   'the',
#   'watery',
#   'part',
#   'of',
#   'the',
#   'world',
#   'it',
#   'is'],
#  ['nothing',
#   'particular',
#   'to',
#   'interest',
#   'me',
#   'on',
#   'shore',
#   'i',
#   'thought',
#   'i',
#   'would',
#   'sail',
#   'about',
#   'a',
#   'little',
#   'and',
#   'see',
#   'the',
#   'watery',
#   'part',
#   'of',
#   'the',
#   'world',
#   'it',
#   'is',
#   'a'],
#  ['particular',
#   'to',
#   'interest',
#   'me',
#   'on',
#   'shore',
#   'i',
#   'thought',
#   'i',
#   'would',
#   'sail',
#   'about',
#   'a',
#   'little',
#   'and',
#   'see',
#   'the',
#   'watery',
#   'part',
#   'of',
#   'the',
#   'world',
#   'it',
#   'is',
#   'a',
#   'way'],
#  ['to',
#   'interest',
#   'me',
#   'on',
#   'shore',
#   'i',
#   'thought',
#   'i',
#   'would',
#   'sail',
#   'about',
#   'a',
#   'little',
#   'and',
#   'see',
#   'the',
#   'watery',
#   'part',
#   'of',
#   'the',
#   'world',
#   'it',
#   'is',
#   'a',
#   'way',
#   'i'],
#  ['interest',
#   'me',
#   'on',
#   'shore',
#   'i',
#   'thought',
#   'i',
#   'would',
#   'sail',
#   'about',
#   'a',
#   'little',
#   'and',
#   'see',
#   'the',
#   'watery',
#   'part',
#   'of',
#   'the',
#   'world',
#   'it',
#   'is',
#   'a',
#   'way',
#   'i',
#   'have'],
#  ['me',
#   'on',
#   'shore',
#   'i',
#   'thought',
#   'i',
#   'would',
#   'sail',
#   'about',
#   'a',
#   'little',
#   'and',
#   'see',
#   'the',
#   'watery',
#   'part',
#   'of',
#   'the',
#   'world',
#   'it',
#   'is',
#   'a',
#   'way',
#   'i',
#   'have',
#   'of'],
#  ['on',
#   'shore',
#   'i',
#   'thought',
#   'i',
#   'would',
#   'sail',
#   'about',
#   'a',
#   'little',
#   'and',
#   'see',
#   'the',
#   'watery',
#   'part',
#   'of',
#   'the',
#   'world',
#   'it',
#   'is',
#   'a',
#   'way',
#   'i',
#   'have',
#   'of',
#   'driving'],
#  ['shore',
#   'i',
#   'thought',
#   'i',
#   'would',
#   'sail',
#   'about',
#   'a',
#   'little',
#   'and',
#   'see',
#   'the',
#   'watery',
#   'part',
#   'of',
#   'the',
#   'world',
#   'it',
#   'is',
#   'a',
#   'way',
#   'i',
#   'have',
#   'of',
#   'driving',
#   'off'],
#  ['i',
#   'thought',
#   'i',
#   'would',
#   'sail',
#   'about',
#   'a',
#   'little',
#   'and',
#   'see',
#   'the',
#   'watery',
#   'part',
#   'of',
#   'the',
#   'world',
#   'it',
#   'is',
#   'a',
#   'way',
#   'i',
#   'have',
#   'of',
#   'driving',
#   'off',
#   'the'],
#  ['thought',
#   'i',
#   'would',
#   'sail',
#   'about',
#   'a',
#   'little',
#   'and',
#   'see',
#   'the',
#   'watery',
#   'part',
#   'of',
#   'the',
#   'world',
#   'it',
#   'is',
#   'a',
#   'way',
#   'i',
#   'have',
#   'of',
#   'driving',
#   'off',
#   'the',
#   'spleen'],
#  ['i',
#   'would',
#   'sail',
#   'about',
#   'a',
#   'little',
#   'and',
#   'see',
#   'the',
#   'watery',
#   'part',
#   'of',
#   'the',
#   'world',
#   'it',
#   'is',
#   'a',
#   'way',
#   'i',
#   'have',
#   'of',
#   'driving',
#   'off',
#   'the',
#   'spleen',
#   'and'],
#  ['would',
#   'sail',
#   'about',
#   'a',
#   'little',
#   'and',
#   'see',
#   'the',
#   'watery',
#   'part',
#   'of',
#   'the',
#   'world',
#   'it',
#   'is',
#   'a',
#   'way',
#   'i',
#   'have',
#   'of',
#   'driving',
#   'off',
#   'the',
#   'spleen',
#   'and',
#   'regulating'],
#  ['sail',
#   'about',
#   'a',
#   'little',
#   'and',
#   'see',
#   'the',
#   'watery',
#   'part',
#   'of',
#   'the',
#   'world',
#   'it',
#   'is',
#   'a',
#   'way',
#   'i',
#   'have',
#   'of',
#   'driving',
#   'off',
#   'the',
#   'spleen',
#   'and',
#   'regulating',
#   'the'],
#  ['about',
#   'a',
#   'little',
#   'and',
#   'see',
#   'the',
#   'watery',
#   'part',
#   'of',
#   'the',
#   'world',
#   'it',
#   'is',
#   'a',
#   'way',
#   'i',
#   'have',
#   'of',
#   'driving',
#   'off',
#   'the',
#   'spleen',
#   'and',
#   'regulating',
#   'the',
#   'circulation'],
#  ['a',
#   'little',
#   'and',
#   'see',
#   'the',
#   'watery',
#   'part',
#   'of',
#   'the',
#   'world',
#   'it',
#   'is',
#   'a',
#   'way',
#   'i',
#   'have',
#   'of',
#   'driving',
#   'off',
#   'the',
#   'spleen',
#   'and',
#   'regulating',
#   'the',
#   'circulation',
#   'whenever'],
#  ['little',
#   'and',
#   'see',
#   'the',
#   'watery',
#   'part',
#   'of',
#   'the',
#   'world',
#   'it',
#   'is',
#   'a',
#   'way',
#   'i',
#   'have',
#   'of',
#   'driving',
#   'off',
#   'the',
#   'spleen',
#   'and',
#   'regulating',
#   'the',
#   'circulation',
#   'whenever',
#   'i'],
#  ['and',
#   'see',
#   'the',
#   'watery',
#   'part',
#   'of',
#   'the',
#   'world',
#   'it',
#   'is',
#   'a',
#   'way',
#   'i',
#   'have',
#   'of',
#   'driving',
#   'off',
#   'the',
#   'spleen',
#   'and',
#   'regulating',
#   'the',
#   'circulation',
#   'whenever',
#   'i',
#   'find'],
#  ['see',
#   'the',
#   'watery',
#   'part',
#   'of',
#   'the',
#   'world',
#   'it',
#   'is',
#   'a',
#   'way',
#   'i',
#   'have',
#   'of',
#   'driving',
#   'off',
#   'the',
#   'spleen',
#   'and',
#   'regulating',
#   'the',
#   'circulation',
#   'whenever',
#   'i',
#   'find',
#   'myself'],
#  ['the',
#   'watery',
#   'part',
#   'of',
#   'the',
#   'world',
#   'it',
#   'is',
#   'a',
#   'way',
#   'i',
#   'have',
#   'of',
#   'driving',
#   'off',
#   'the',
#   'spleen',
#   'and',
#   'regulating',
#   'the',
#   'circulation',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'growing'],
#  ['watery',
#   'part',
#   'of',
#   'the',
#   'world',
#   'it',
#   'is',
#   'a',
#   'way',
#   'i',
#   'have',
#   'of',
#   'driving',
#   'off',
#   'the',
#   'spleen',
#   'and',
#   'regulating',
#   'the',
#   'circulation',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'growing',
#   'grim'],
#  ['part',
#   'of',
#   'the',
#   'world',
#   'it',
#   'is',
#   'a',
#   'way',
#   'i',
#   'have',
#   'of',
#   'driving',
#   'off',
#   'the',
#   'spleen',
#   'and',
#   'regulating',
#   'the',
#   'circulation',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'growing',
#   'grim',
#   'about'],
#  ['of',
#   'the',
#   'world',
#   'it',
#   'is',
#   'a',
#   'way',
#   'i',
#   'have',
#   'of',
#   'driving',
#   'off',
#   'the',
#   'spleen',
#   'and',
#   'regulating',
#   'the',
#   'circulation',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'growing',
#   'grim',
#   'about',
#   'the'],
#  ['the',
#   'world',
#   'it',
#   'is',
#   'a',
#   'way',
#   'i',
#   'have',
#   'of',
#   'driving',
#   'off',
#   'the',
#   'spleen',
#   'and',
#   'regulating',
#   'the',
#   'circulation',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'growing',
#   'grim',
#   'about',
#   'the',
#   'mouth'],
#  ['world',
#   'it',
#   'is',
#   'a',
#   'way',
#   'i',
#   'have',
#   'of',
#   'driving',
#   'off',
#   'the',
#   'spleen',
#   'and',
#   'regulating',
#   'the',
#   'circulation',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'growing',
#   'grim',
#   'about',
#   'the',
#   'mouth',
#   'whenever'],
#  ['it',
#   'is',
#   'a',
#   'way',
#   'i',
#   'have',
#   'of',
#   'driving',
#   'off',
#   'the',
#   'spleen',
#   'and',
#   'regulating',
#   'the',
#   'circulation',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'growing',
#   'grim',
#   'about',
#   'the',
#   'mouth',
#   'whenever',
#   'it'],
#  ['is',
#   'a',
#   'way',
#   'i',
#   'have',
#   'of',
#   'driving',
#   'off',
#   'the',
#   'spleen',
#   'and',
#   'regulating',
#   'the',
#   'circulation',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'growing',
#   'grim',
#   'about',
#   'the',
#   'mouth',
#   'whenever',
#   'it',
#   'is'],
#  ['a',
#   'way',
#   'i',
#   'have',
#   'of',
#   'driving',
#   'off',
#   'the',
#   'spleen',
#   'and',
#   'regulating',
#   'the',
#   'circulation',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'growing',
#   'grim',
#   'about',
#   'the',
#   'mouth',
#   'whenever',
#   'it',
#   'is',
#   'a'],
#  ['way',
#   'i',
#   'have',
#   'of',
#   'driving',
#   'off',
#   'the',
#   'spleen',
#   'and',
#   'regulating',
#   'the',
#   'circulation',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'growing',
#   'grim',
#   'about',
#   'the',
#   'mouth',
#   'whenever',
#   'it',
#   'is',
#   'a',
#   'damp'],
#  ['i',
#   'have',
#   'of',
#   'driving',
#   'off',
#   'the',
#   'spleen',
#   'and',
#   'regulating',
#   'the',
#   'circulation',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'growing',
#   'grim',
#   'about',
#   'the',
#   'mouth',
#   'whenever',
#   'it',
#   'is',
#   'a',
#   'damp',
#   'drizzly'],
#  ['have',
#   'of',
#   'driving',
#   'off',
#   'the',
#   'spleen',
#   'and',
#   'regulating',
#   'the',
#   'circulation',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'growing',
#   'grim',
#   'about',
#   'the',
#   'mouth',
#   'whenever',
#   'it',
#   'is',
#   'a',
#   'damp',
#   'drizzly',
#   'november'],
#  ['of',
#   'driving',
#   'off',
#   'the',
#   'spleen',
#   'and',
#   'regulating',
#   'the',
#   'circulation',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'growing',
#   'grim',
#   'about',
#   'the',
#   'mouth',
#   'whenever',
#   'it',
#   'is',
#   'a',
#   'damp',
#   'drizzly',
#   'november',
#   'in'],
#  ['driving',
#   'off',
#   'the',
#   'spleen',
#   'and',
#   'regulating',
#   'the',
#   'circulation',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'growing',
#   'grim',
#   'about',
#   'the',
#   'mouth',
#   'whenever',
#   'it',
#   'is',
#   'a',
#   'damp',
#   'drizzly',
#   'november',
#   'in',
#   'my'],
#  ['off',
#   'the',
#   'spleen',
#   'and',
#   'regulating',
#   'the',
#   'circulation',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'growing',
#   'grim',
#   'about',
#   'the',
#   'mouth',
#   'whenever',
#   'it',
#   'is',
#   'a',
#   'damp',
#   'drizzly',
#   'november',
#   'in',
#   'my',
#   'soul'],
#  ['the',
#   'spleen',
#   'and',
#   'regulating',
#   'the',
#   'circulation',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'growing',
#   'grim',
#   'about',
#   'the',
#   'mouth',
#   'whenever',
#   'it',
#   'is',
#   'a',
#   'damp',
#   'drizzly',
#   'november',
#   'in',
#   'my',
#   'soul',
#   'whenever'],
#  ['spleen',
#   'and',
#   'regulating',
#   'the',
#   'circulation',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'growing',
#   'grim',
#   'about',
#   'the',
#   'mouth',
#   'whenever',
#   'it',
#   'is',
#   'a',
#   'damp',
#   'drizzly',
#   'november',
#   'in',
#   'my',
#   'soul',
#   'whenever',
#   'i'],
#  ['and',
#   'regulating',
#   'the',
#   'circulation',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'growing',
#   'grim',
#   'about',
#   'the',
#   'mouth',
#   'whenever',
#   'it',
#   'is',
#   'a',
#   'damp',
#   'drizzly',
#   'november',
#   'in',
#   'my',
#   'soul',
#   'whenever',
#   'i',
#   'find'],
#  ['regulating',
#   'the',
#   'circulation',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'growing',
#   'grim',
#   'about',
#   'the',
#   'mouth',
#   'whenever',
#   'it',
#   'is',
#   'a',
#   'damp',
#   'drizzly',
#   'november',
#   'in',
#   'my',
#   'soul',
#   'whenever',
#   'i',
#   'find',
#   'myself'],
#  ['the',
#   'circulation',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'growing',
#   'grim',
#   'about',
#   'the',
#   'mouth',
#   'whenever',
#   'it',
#   'is',
#   'a',
#   'damp',
#   'drizzly',
#   'november',
#   'in',
#   'my',
#   'soul',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'involuntarily'],
#  ['circulation',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'growing',
#   'grim',
#   'about',
#   'the',
#   'mouth',
#   'whenever',
#   'it',
#   'is',
#   'a',
#   'damp',
#   'drizzly',
#   'november',
#   'in',
#   'my',
#   'soul',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'involuntarily',
#   'pausing'],
#  ['whenever',
#   'i',
#   'find',
#   'myself',
#   'growing',
#   'grim',
#   'about',
#   'the',
#   'mouth',
#   'whenever',
#   'it',
#   'is',
#   'a',
#   'damp',
#   'drizzly',
#   'november',
#   'in',
#   'my',
#   'soul',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'involuntarily',
#   'pausing',
#   'before'],
#  ['i',
#   'find',
#   'myself',
#   'growing',
#   'grim',
#   'about',
#   'the',
#   'mouth',
#   'whenever',
#   'it',
#   'is',
#   'a',
#   'damp',
#   'drizzly',
#   'november',
#   'in',
#   'my',
#   'soul',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'involuntarily',
#   'pausing',
#   'before',
#   'coffin'],
#  ['find',
#   'myself',
#   'growing',
#   'grim',
#   'about',
#   'the',
#   'mouth',
#   'whenever',
#   'it',
#   'is',
#   'a',
#   'damp',
#   'drizzly',
#   'november',
#   'in',
#   'my',
#   'soul',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'involuntarily',
#   'pausing',
#   'before',
#   'coffin',
#   'warehouses'],
#  ['myself',
#   'growing',
#   'grim',
#   'about',
#   'the',
#   'mouth',
#   'whenever',
#   'it',
#   'is',
#   'a',
#   'damp',
#   'drizzly',
#   'november',
#   'in',
#   'my',
#   'soul',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'involuntarily',
#   'pausing',
#   'before',
#   'coffin',
#   'warehouses',
#   'and'],
#  ['growing',
#   'grim',
#   'about',
#   'the',
#   'mouth',
#   'whenever',
#   'it',
#   'is',
#   'a',
#   'damp',
#   'drizzly',
#   'november',
#   'in',
#   'my',
#   'soul',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'involuntarily',
#   'pausing',
#   'before',
#   'coffin',
#   'warehouses',
#   'and',
#   'bringing'],
#  ['grim',
#   'about',
#   'the',
#   'mouth',
#   'whenever',
#   'it',
#   'is',
#   'a',
#   'damp',
#   'drizzly',
#   'november',
#   'in',
#   'my',
#   'soul',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'involuntarily',
#   'pausing',
#   'before',
#   'coffin',
#   'warehouses',
#   'and',
#   'bringing',
#   'up'],
#  ['about',
#   'the',
#   'mouth',
#   'whenever',
#   'it',
#   'is',
#   'a',
#   'damp',
#   'drizzly',
#   'november',
#   'in',
#   'my',
#   'soul',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'involuntarily',
#   'pausing',
#   'before',
#   'coffin',
#   'warehouses',
#   'and',
#   'bringing',
#   'up',
#   'the'],
#  ['the',
#   'mouth',
#   'whenever',
#   'it',
#   'is',
#   'a',
#   'damp',
#   'drizzly',
#   'november',
#   'in',
#   'my',
#   'soul',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'involuntarily',
#   'pausing',
#   'before',
#   'coffin',
#   'warehouses',
#   'and',
#   'bringing',
#   'up',
#   'the',
#   'rear'],
#  ['mouth',
#   'whenever',
#   'it',
#   'is',
#   'a',
#   'damp',
#   'drizzly',
#   'november',
#   'in',
#   'my',
#   'soul',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'involuntarily',
#   'pausing',
#   'before',
#   'coffin',
#   'warehouses',
#   'and',
#   'bringing',
#   'up',
#   'the',
#   'rear',
#   'of'],
#  ['whenever',
#   'it',
#   'is',
#   'a',
#   'damp',
#   'drizzly',
#   'november',
#   'in',
#   'my',
#   'soul',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'involuntarily',
#   'pausing',
#   'before',
#   'coffin',
#   'warehouses',
#   'and',
#   'bringing',
#   'up',
#   'the',
#   'rear',
#   'of',
#   'every'],
#  ['it',
#   'is',
#   'a',
#   'damp',
#   'drizzly',
#   'november',
#   'in',
#   'my',
#   'soul',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'involuntarily',
#   'pausing',
#   'before',
#   'coffin',
#   'warehouses',
#   'and',
#   'bringing',
#   'up',
#   'the',
#   'rear',
#   'of',
#   'every',
#   'funeral'],
#  ['is',
#   'a',
#   'damp',
#   'drizzly',
#   'november',
#   'in',
#   'my',
#   'soul',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'involuntarily',
#   'pausing',
#   'before',
#   'coffin',
#   'warehouses',
#   'and',
#   'bringing',
#   'up',
#   'the',
#   'rear',
#   'of',
#   'every',
#   'funeral',
#   'i'],
#  ['a',
#   'damp',
#   'drizzly',
#   'november',
#   'in',
#   'my',
#   'soul',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'involuntarily',
#   'pausing',
#   'before',
#   'coffin',
#   'warehouses',
#   'and',
#   'bringing',
#   'up',
#   'the',
#   'rear',
#   'of',
#   'every',
#   'funeral',
#   'i',
#   'meet'],
#  ['damp',
#   'drizzly',
#   'november',
#   'in',
#   'my',
#   'soul',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'involuntarily',
#   'pausing',
#   'before',
#   'coffin',
#   'warehouses',
#   'and',
#   'bringing',
#   'up',
#   'the',
#   'rear',
#   'of',
#   'every',
#   'funeral',
#   'i',
#   'meet',
#   'and'],
#  ['drizzly',
#   'november',
#   'in',
#   'my',
#   'soul',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'involuntarily',
#   'pausing',
#   'before',
#   'coffin',
#   'warehouses',
#   'and',
#   'bringing',
#   'up',
#   'the',
#   'rear',
#   'of',
#   'every',
#   'funeral',
#   'i',
#   'meet',
#   'and',
#   'especially'],
#  ['november',
#   'in',
#   'my',
#   'soul',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'involuntarily',
#   'pausing',
#   'before',
#   'coffin',
#   'warehouses',
#   'and',
#   'bringing',
#   'up',
#   'the',
#   'rear',
#   'of',
#   'every',
#   'funeral',
#   'i',
#   'meet',
#   'and',
#   'especially',
#   'whenever'],
#  ['in',
#   'my',
#   'soul',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'involuntarily',
#   'pausing',
#   'before',
#   'coffin',
#   'warehouses',
#   'and',
#   'bringing',
#   'up',
#   'the',
#   'rear',
#   'of',
#   'every',
#   'funeral',
#   'i',
#   'meet',
#   'and',
#   'especially',
#   'whenever',
#   'my'],
#  ['my',
#   'soul',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'involuntarily',
#   'pausing',
#   'before',
#   'coffin',
#   'warehouses',
#   'and',
#   'bringing',
#   'up',
#   'the',
#   'rear',
#   'of',
#   'every',
#   'funeral',
#   'i',
#   'meet',
#   'and',
#   'especially',
#   'whenever',
#   'my',
#   'hypos'],
#  ['soul',
#   'whenever',
#   'i',
#   'find',
#   'myself',
#   'involuntarily',
#   'pausing',
#   'before',
#   'coffin',
#   'warehouses',
#   'and',
#   'bringing',
#   'up',
#   'the',
#   'rear',
#   'of',
#   'every',
#   'funeral',
#   'i',
#   'meet',
#   'and',
#   'especially',
#   'whenever',
#   'my',
#   'hypos',
#   'get'],
#  ['whenever',
#   'i',
#   'find',
#   'myself',
#   'involuntarily',
#   'pausing',
#   'before',
#   'coffin',
#   'warehouses',
#   'and',
#   'bringing',
#   'up',
#   'the',
#   'rear',
#   'of',
#   'every',
#   'funeral',
#   'i',
#   'meet',
#   'and',
#   'especially',
#   'whenever',
#   'my',
#   'hypos',
#   'get',
#   'such'],
#  ['i',
#   'find',
#   'myself',
#   'involuntarily',
#   'pausing',
#   'before',
#   'coffin',
#   'warehouses',
#   'and',
#   'bringing',
#   'up',
#   'the',
#   'rear',
#   'of',
#   'every',
#   'funeral',
#   'i',
#   'meet',
#   'and',
#   'especially',
#   'whenever',
#   'my',
#   'hypos',
#   'get',
#   'such',
#   'an'],
#  ['find',
#   'myself',
#   'involuntarily',
#   'pausing',
#   'before',
#   'coffin',
#   'warehouses',
#   'and',
#   'bringing',
#   'up',
#   'the',
#   'rear',
#   'of',
#   'every',
#   'funeral',
#   'i',
#   'meet',
#   'and',
#   'especially',
#   'whenever',
#   'my',
#   'hypos',
#   'get',
#   'such',
#   'an',
#   'upper'],
#  ['myself',
#   'involuntarily',
#   'pausing',
#   'before',
#   'coffin',
#   'warehouses',
#   'and',
#   'bringing',
#   'up',
#   'the',
#   'rear',
#   'of',
#   'every',
#   'funeral',
#   'i',
#   'meet',
#   'and',
#   'especially',
#   'whenever',
#   'my',
#   'hypos',
#   'get',
#   'such',
#   'an',
#   'upper',
#   'hand'],
#  ['involuntarily',
#   'pausing',
#   'before',
#   'coffin',
#   'warehouses',
#   'and',
#   'bringing',
#   'up',
#   'the',
#   'rear',
#   'of',
#   'every',
#   'funeral',
#   'i',
#   'meet',
#   'and',
#   'especially',
#   'whenever',
#   'my',
#   'hypos',
#   'get',
#   'such',
#   'an',
#   'upper',
#   'hand',
#   'of'],
#  ['pausing',
#   'before',
#   'coffin',
#   'warehouses',
#   'and',
#   'bringing',
#   'up',
#   'the',
#   'rear',
#   'of',
#   'every',
#   'funeral',
#   'i',
#   'meet',
#   'and',
#   'especially',
#   'whenever',
#   'my',
#   'hypos',
#   'get',
#   'such',
#   'an',
#   'upper',
#   'hand',
#   'of',
#   'me'],
#  ['before',
#   'coffin',
#   'warehouses',
#   'and',
#   'bringing',
#   'up',
#   'the',
#   'rear',
#   'of',
#   'every',
#   'funeral',
#   'i',
#   'meet',
#   'and',
#   'especially',
#   'whenever',
#   'my',
#   'hypos',
#   'get',
#   'such',
#   'an',
#   'upper',
#   'hand',
#   'of',
#   'me',
#   'that'],
#  ['coffin',
#   'warehouses',
#   'and',
#   'bringing',
#   'up',
#   'the',
#   'rear',
#   'of',
#   'every',
#   'funeral',
#   'i',
#   'meet',
#   'and',
#   'especially',
#   'whenever',
#   'my',
#   'hypos',
#   'get',
#   'such',
#   'an',
#   'upper',
#   'hand',
#   'of',
#   'me',
#   'that',
#   'it'],
#  ['warehouses',
#   'and',
#   'bringing',
#   'up',
#   'the',
#   'rear',
#   'of',
#   'every',
#   'funeral',
#   'i',
#   'meet',
#   'and',
#   'especially',
#   'whenever',
#   'my',
#   'hypos',
#   'get',
#   'such',
#   'an',
#   'upper',
#   'hand',
#   'of',
#   'me',
#   'that',
#   'it',
#   'requires'],
#  ['and',
#   'bringing',
#   'up',
#   'the',
#   'rear',
#   'of',
#   'every',
#   'funeral',
#   'i',
#   'meet',
#   'and',
#   'especially',
#   'whenever',
#   'my',
#   'hypos',
#   'get',
#   'such',
#   'an',
#   'upper',
#   'hand',
#   'of',
#   'me',
#   'that',
#   'it',
#   'requires',
#   'a'],
#  ['bringing',
#   'up',
#   'the',
#   'rear',
#   'of',
#   'every',
#   'funeral',
#   'i',
#   'meet',
#   'and',
#   'especially',
#   'whenever',
#   'my',
#   'hypos',
#   'get',
#   'such',
#   'an',
#   'upper',
#   'hand',
#   'of',
#   'me',
#   'that',
#   'it',
#   'requires',
#   'a',
#   'strong'],
#  ['up',
#   'the',
#   'rear',
#   'of',
#   'every',
#   'funeral',
#   'i',
#   'meet',
#   'and',
#   'especially',
#   'whenever',
#   'my',
#   'hypos',
#   'get',
#   'such',
#   'an',
#   'upper',
#   'hand',
#   'of',
#   'me',
#   'that',
#   'it',
#   'requires',
#   'a',
#   'strong',
#   'moral'],
#  ['the',
#   'rear',
#   'of',
#   'every',
#   'funeral',
#   'i',
#   'meet',
#   'and',
#   'especially',
#   'whenever',
#   'my',
#   'hypos',
#   'get',
#   'such',
#   'an',
#   'upper',
#   'hand',
#   'of',
#   'me',
#   'that',
#   'it',
#   'requires',
#   'a',
#   'strong',
#   'moral',
#   'principle'],
#  ['rear',
#   'of',
#   'every',
#   'funeral',
#   'i',
#   'meet',
#   'and',
#   'especially',
#   'whenever',
#   'my',
#   'hypos',
#   'get',
#   'such',
#   'an',
#   'upper',
#   'hand',
#   'of',
#   'me',
#   'that',
#   'it',
#   'requires',
#   'a',
#   'strong',
#   'moral',
#   'principle',
#   'to'],
#  ['of',
#   'every',
#   'funeral',
#   'i',
#   'meet',
#   'and',
#   'especially',
#   'whenever',
#   'my',
#   'hypos',
#   'get',
#   'such',
#   'an',
#   'upper',
#   'hand',
#   'of',
#   'me',
#   'that',
#   'it',
#   'requires',
#   'a',
#   'strong',
#   'moral',
#   'principle',
#   'to',
#   'prevent'],
#  ['every',
#   'funeral',
#   'i',
#   'meet',
#   'and',
#   'especially',
#   'whenever',
#   'my',
#   'hypos',
#   'get',
#   'such',
#   'an',
#   'upper',
#   'hand',
#   'of',
#   'me',
#   'that',
#   'it',
#   'requires',
#   'a',
#   'strong',
#   'moral',
#   'principle',
#   'to',
#   'prevent',
#   'me'],
#  ['funeral',
#   'i',
#   'meet',
#   'and',
#   'especially',
#   'whenever',
#   'my',
#   'hypos',
#   'get',
#   'such',
#   'an',
#   'upper',
#   'hand',
#   'of',
#   'me',
#   'that',
#   'it',
#   'requires',
#   'a',
#   'strong',
#   'moral',
#   'principle',
#   'to',
#   'prevent',
#   'me',
#   'from'],
#  ['i',
#   'meet',
#   'and',
#   'especially',
#   'whenever',
#   'my',
#   'hypos',
#   'get',
#   'such',
#   'an',
#   'upper',
#   'hand',
#   'of',
#   'me',
#   'that',
#   'it',
#   'requires',
#   'a',
#   'strong',
#   'moral',
#   'principle',
#   'to',
#   'prevent',
#   'me',
#   'from',
#   'deliberately'],
#  ['meet',
#   'and',
#   'especially',
#   'whenever',
#   'my',
#   'hypos',
#   'get',
#   'such',
#   'an',
#   'upper',
#   'hand',
#   'of',
#   'me',
#   'that',
#   'it',
#   'requires',
#   'a',
#   'strong',
#   'moral',
#   'principle',
#   'to',
#   'prevent',
#   'me',
#   'from',
#   'deliberately',
#   'stepping'],
#  ['and',
#   'especially',
#   'whenever',
#   'my',
#   'hypos',
#   'get',
#   'such',
#   'an',
#   'upper',
#   'hand',
#   'of',
#   'me',
#   'that',
#   'it',
#   'requires',
#   'a',
#   'strong',
#   'moral',
#   'principle',
#   'to',
#   'prevent',
#   'me',
#   'from',
#   'deliberately',
#   'stepping',
#   'into'],
#  ['especially',
#   'whenever',
#   'my',
#   'hypos',
#   'get',
#   'such',
#   'an',
#   'upper',
#   'hand',
#   'of',
#   'me',
#   'that',
#   'it',
#   'requires',
#   'a',
#   'strong',
#   'moral',
#   'principle',
#   'to',
#   'prevent',
#   'me',
#   'from',
#   'deliberately',
#   'stepping',
#   'into',
#   'the'],
#  ['whenever',
#   'my',
#   'hypos',
#   'get',
#   'such',
#   'an',
#   'upper',
#   'hand',
#   'of',
#   'me',
#   'that',
#   'it',
#   'requires',
#   'a',
#   'strong',
#   'moral',
#   'principle',
#   'to',
#   'prevent',
#   'me',
#   'from',
#   'deliberately',
#   'stepping',
#   'into',
#   'the',
#   'street'],
#  ['my',
#   'hypos',
#   'get',
#   'such',
#   'an',
#   'upper',
#   'hand',
#   'of',
#   'me',
#   'that',
#   'it',
#   'requires',
#   'a',
#   'strong',
#   'moral',
#   'principle',
#   'to',
#   'prevent',
#   'me',
#   'from',
#   'deliberately',
#   'stepping',
#   'into',
#   'the',
#   'street',
#   'and'],
#  ['hypos',
#   'get',
#   'such',
#   'an',
#   'upper',
#   'hand',
#   'of',
#   'me',
#   'that',
#   'it',
#   'requires',
#   'a',
#   'strong',
#   'moral',
#   'principle',
#   'to',
#   'prevent',
#   'me',
#   'from',
#   'deliberately',
#   'stepping',
#   'into',
#   'the',
#   'street',
#   'and',
#   'methodically'],
#  ['get',
#   'such',
#   'an',
#   'upper',
#   'hand',
#   'of',
#   'me',
#   'that',
#   'it',
#   'requires',
#   'a',
#   'strong',
#   'moral',
#   'principle',
#   'to',
#   'prevent',
#   'me',
#   'from',
#   'deliberately',
#   'stepping',
#   'into',
#   'the',
#   'street',
#   'and',
#   'methodically',
#   'knocking'],
#  ['such',
#   'an',
#   'upper',
#   'hand',
#   'of',
#   'me',
#   'that',
#   'it',
#   'requires',
#   'a',
#   'strong',
#   'moral',
#   'principle',
#   'to',
#   'prevent',
#   'me',
#   'from',
#   'deliberately',
#   'stepping',
#   'into',
#   'the',
#   'street',
#   'and',
#   'methodically',
#   'knocking',
#   'people'],
#  ['an',
#   'upper',
#   'hand',
#   'of',
#   'me',
#   'that',
#   'it',
#   'requires',
#   'a',
#   'strong',
#   'moral',
#   'principle',
#   'to',
#   'prevent',
#   'me',
#   'from',
#   'deliberately',
#   'stepping',
#   'into',
#   'the',
#   'street',
#   'and',
#   'methodically',
#   'knocking',
#   'people',
#   "'s"],
#  ['upper',
#   'hand',
#   'of',
#   'me',
#   'that',
#   'it',
#   'requires',
#   'a',
#   'strong',
#   'moral',
#   'principle',
#   'to',
#   'prevent',
#   'me',
#   'from',
#   'deliberately',
#   'stepping',
#   'into',
#   'the',
#   'street',
#   'and',
#   'methodically',
#   'knocking',
#   'people',
#   "'s",
#   'hats'],
#  ['hand',
#   'of',
#   'me',
#   'that',
#   'it',
#   'requires',
#   'a',
#   'strong',
#   'moral',
#   'principle',
#   'to',
#   'prevent',
#   'me',
#   'from',
#   'deliberately',
#   'stepping',
#   'into',
#   'the',
#   'street',
#   'and',
#   'methodically',
#   'knocking',
#   'people',
#   "'s",
#   'hats',
#   'off'],
#  ['of',
#   'me',
#   'that',
#   'it',
#   'requires',
#   'a',
#   'strong',
#   'moral',
#   'principle',
#   'to',
#   'prevent',
#   'me',
#   'from',
#   'deliberately',
#   'stepping',
#   'into',
#   'the',
#   'street',
#   'and',
#   'methodically',
#   'knocking',
#   'people',
#   "'s",
#   'hats',
#   'off',
#   'then'],
#  ['me',
#   'that',
#   'it',
#   'requires',
#   'a',
#   'strong',
#   'moral',
#   'principle',
#   'to',
#   'prevent',
#   'me',
#   'from',
#   'deliberately',
#   'stepping',
#   'into',
#   'the',
#   'street',
#   'and',
#   'methodically',
#   'knocking',
#   'people',
#   "'s",
#   'hats',
#   'off',
#   'then',
#   'i'],
#  ['that',
#   'it',
#   'requires',
#   'a',
#   'strong',
#   'moral',
#   'principle',
#   'to',
#   'prevent',
#   'me',
#   'from',
#   'deliberately',
#   'stepping',
#   'into',
#   'the',
#   'street',
#   'and',
#   'methodically',
#   'knocking',
#   'people',
#   "'s",
#   'hats',
#   'off',
#   'then',
#   'i',
#   'account'],
#  ['it',
#   'requires',
#   'a',
#   'strong',
#   'moral',
#   'principle',
#   'to',
#   'prevent',
#   'me',
#   'from',
#   'deliberately',
#   'stepping',
#   'into',
#   'the',
#   'street',
#   'and',
#   'methodically',
#   'knocking',
#   'people',
#   "'s",
#   'hats',
#   'off',
#   'then',
#   'i',
#   'account',
#   'it'],
#  ['requires',
#   'a',
#   'strong',
#   'moral',
#   'principle',
#   'to',
#   'prevent',
#   'me',
#   'from',
#   'deliberately',
#   'stepping',
#   'into',
#   'the',
#   'street',
#   'and',
#   'methodically',
#   'knocking',
#   'people',
#   "'s",
#   'hats',
#   'off',
#   'then',
#   'i',
#   'account',
#   'it',
#   'high'],
#  ['a',
#   'strong',
#   'moral',
#   'principle',
#   'to',
#   'prevent',
#   'me',
#   'from',
#   'deliberately',
#   'stepping',
#   'into',
#   'the',
#   'street',
#   'and',
#   'methodically',
#   'knocking',
#   'people',
#   "'s",
#   'hats',
#   'off',
#   'then',
#   'i',
#   'account',
#   'it',
#   'high',
#   'time'],
#  ['strong',
#   'moral',
#   'principle',
#   'to',
#   'prevent',
#   'me',
#   'from',
#   'deliberately',
#   'stepping',
#   'into',
#   'the',
#   'street',
#   'and',
#   'methodically',
#   'knocking',
#   'people',
#   "'s",
#   'hats',
#   'off',
#   'then',
#   'i',
#   'account',
#   'it',
#   'high',
#   'time',
#   'to'],
#  ['moral',
#   'principle',
#   'to',
#   'prevent',
#   'me',
#   'from',
#   'deliberately',
#   'stepping',
#   'into',
#   'the',
#   'street',
#   'and',
#   'methodically',
#   'knocking',
#   'people',
#   "'s",
#   'hats',
#   'off',
#   'then',
#   'i',
#   'account',
#   'it',
#   'high',
#   'time',
#   'to',
#   'get'],
#  ['principle',
#   'to',
#   'prevent',
#   'me',
#   'from',
#   'deliberately',
#   'stepping',
#   'into',
#   'the',
#   'street',
#   'and',
#   'methodically',
#   'knocking',
#   'people',
#   "'s",
#   'hats',
#   'off',
#   'then',
#   'i',
#   'account',
#   'it',
#   'high',
#   'time',
#   'to',
#   'get',
#   'to'],
#  ['to',
#   'prevent',
#   'me',
#   'from',
#   'deliberately',
#   'stepping',
#   'into',
#   'the',
#   'street',
#   'and',
#   'methodically',
#   'knocking',
#   'people',
#   "'s",
#   'hats',
#   'off',
#   'then',
#   'i',
#   'account',
#   'it',
#   'high',
#   'time',
#   'to',
#   'get',
#   'to',
#   'sea'],
#  ['prevent',
#   'me',
#   'from',
#   'deliberately',
#   'stepping',
#   'into',
#   'the',
#   'street',
#   'and',
#   'methodically',
#   'knocking',
#   'people',
#   "'s",
#   'hats',
#   'off',
#   'then',
#   'i',
#   'account',
#   'it',
#   'high',
#   'time',
#   'to',
#   'get',
#   'to',
#   'sea',
#   'as'],
#  ['me',
#   'from',
#   'deliberately',
#   'stepping',
#   'into',
#   'the',
#   'street',
#   'and',
#   'methodically',
#   'knocking',
#   'people',
#   "'s",
#   'hats',
#   'off',
#   'then',
#   'i',
#   'account',
#   'it',
#   'high',
#   'time',
#   'to',
#   'get',
#   'to',
#   'sea',
#   'as',
#   'soon'],
#  ['from',
#   'deliberately',
#   'stepping',
#   'into',
#   'the',
#   'street',
#   'and',
#   'methodically',
#   'knocking',
#   'people',
#   "'s",
#   'hats',
#   'off',
#   'then',
#   'i',
#   'account',
#   'it',
#   'high',
#   'time',
#   'to',
#   'get',
#   'to',
#   'sea',
#   'as',
#   'soon',
#   'as'],
#  ['deliberately',
#   'stepping',
#   'into',
#   'the',
#   'street',
#   'and',
#   'methodically',
#   'knocking',
#   'people',
#   "'s",
#   'hats',
#   'off',
#   'then',
#   'i',
#   'account',
#   'it',
#   'high',
#   'time',
#   'to',
#   'get',
#   'to',
#   'sea',
#   'as',
#   'soon',
#   'as',
#   'i'],
#  ['stepping',
#   'into',
#   'the',
#   'street',
#   'and',
#   'methodically',
#   'knocking',
#   'people',
#   "'s",
#   'hats',
#   'off',
#   'then',
#   'i',
#   'account',
#   'it',
#   'high',
#   'time',
#   'to',
#   'get',
#   'to',
#   'sea',
#   'as',
#   'soon',
#   'as',
#   'i',
#   'can'],
#  ['into',
#   'the',
#   'street',
#   'and',
#   'methodically',
#   'knocking',
#   'people',
#   "'s",
#   'hats',
#   'off',
#   'then',
#   'i',
#   'account',
#   'it',
#   'high',
#   'time',
#   'to',
#   'get',
#   'to',
#   'sea',
#   'as',
#   'soon',
#   'as',
#   'i',
#   'can',
#   'this'],
#  ['the',
#   'street',
#   'and',
#   'methodically',
#   'knocking',
#   'people',
#   "'s",
#   'hats',
#   'off',
#   'then',
#   'i',
#   'account',
#   'it',
#   'high',
#   'time',
#   'to',
#   'get',
#   'to',
#   'sea',
#   'as',
#   'soon',
#   'as',
#   'i',
#   'can',
#   'this',
#   'is'],
#  ['street',
#   'and',
#   'methodically',
#   'knocking',
#   'people',
#   "'s",
#   'hats',
#   'off',
#   'then',
#   'i',
#   'account',
#   'it',
#   'high',
#   'time',
#   'to',
#   'get',
#   'to',
#   'sea',
#   'as',
#   'soon',
#   'as',
#   'i',
#   'can',
#   'this',
#   'is',
#   'my'],
#  ['and',
#   'methodically',
#   'knocking',
#   'people',
#   "'s",
#   'hats',
#   'off',
#   'then',
#   'i',
#   'account',
#   'it',
#   'high',
#   'time',
#   'to',
#   'get',
#   'to',
#   'sea',
#   'as',
#   'soon',
#   'as',
#   'i',
#   'can',
#   'this',
#   'is',
#   'my',
#   'substitute'],
#  ['methodically',
#   'knocking',
#   'people',
#   "'s",
#   'hats',
#   'off',
#   'then',
#   'i',
#   'account',
#   'it',
#   'high',
#   'time',
#   'to',
#   'get',
#   'to',
#   'sea',
#   'as',
#   'soon',
#   'as',
#   'i',
#   'can',
#   'this',
#   'is',
#   'my',
#   'substitute',
#   'for'],
#  ['knocking',
#   'people',
#   "'s",
#   'hats',
#   'off',
#   'then',
#   'i',
#   'account',
#   'it',
#   'high',
#   'time',
#   'to',
#   'get',
#   'to',
#   'sea',
#   'as',
#   'soon',
#   'as',
#   'i',
#   'can',
#   'this',
#   'is',
#   'my',
#   'substitute',
#   'for',
#   'pistol'],
#  ['people',
#   "'s",
#   'hats',
#   'off',
#   'then',
#   'i',
#   'account',
#   'it',
#   'high',
#   'time',
#   'to',
#   'get',
#   'to',
#   'sea',
#   'as',
#   'soon',
#   'as',
#   'i',
#   'can',
#   'this',
#   'is',
#   'my',
#   'substitute',
#   'for',
#   'pistol',
#   'and'],
#  ["'s",
#   'hats',
#   'off',
#   'then',
#   'i',
#   'account',
#   'it',
#   'high',
#   'time',
#   'to',
#   'get',
#   'to',
#   'sea',
#   'as',
#   'soon',
#   'as',
#   'i',
#   'can',
#   'this',
#   'is',
#   'my',
#   'substitute',
#   'for',
#   'pistol',
#   'and',
#   'ball'],
#  ['hats',
#   'off',
#   'then',
#   'i',
#   'account',
#   'it',
#   'high',
#   'time',
#   'to',
#   'get',
#   'to',
#   'sea',
#   'as',
#   'soon',
#   'as',
#   'i',
#   'can',
#   'this',
#   'is',
#   'my',
#   'substitute',
#   'for',
#   'pistol',
#   'and',
#   'ball',
#   'with'],
#  ['off',
#   'then',
#   'i',
#   'account',
#   'it',
#   'high',
#   'time',
#   'to',
#   'get',
#   'to',
#   'sea',
#   'as',
#   'soon',
#   'as',
#   'i',
#   'can',
#   'this',
#   'is',
#   'my',
#   'substitute',
#   'for',
#   'pistol',
#   'and',
#   'ball',
#   'with',
#   'a'],
#  ['then',
#   'i',
#   'account',
#   'it',
#   'high',
#   'time',
#   'to',
#   'get',
#   'to',
#   'sea',
#   'as',
#   'soon',
#   'as',
#   'i',
#   'can',
#   'this',
#   'is',
#   'my',
#   'substitute',
#   'for',
#   'pistol',
#   'and',
#   'ball',
#   'with',
#   'a',
#   'philosophical'],
#  ['i',
#   'account',
#   'it',
#   'high',
#   'time',
#   'to',
#   'get',
#   'to',
#   'sea',
#   'as',
#   'soon',
#   'as',
#   'i',
#   'can',
#   'this',
#   'is',
#   'my',
#   'substitute',
#   'for',
#   'pistol',
#   'and',
#   'ball',
#   'with',
#   'a',
#   'philosophical',
#   'flourish'],
#  ['account',
#   'it',
#   'high',
#   'time',
#   'to',
#   'get',
#   'to',
#   'sea',
#   'as',
#   'soon',
#   'as',
#   'i',
#   'can',
#   'this',
#   'is',
#   'my',
#   'substitute',
#   'for',
#   'pistol',
#   'and',
#   'ball',
#   'with',
#   'a',
#   'philosophical',
#   'flourish',
#   'cato'],
#  ['it',
#   'high',
#   'time',
#   'to',
#   'get',
#   'to',
#   'sea',
#   'as',
#   'soon',
#   'as',
#   'i',
#   'can',
#   'this',
#   'is',
#   'my',
#   'substitute',
#   'for',
#   'pistol',
#   'and',
#   'ball',
#   'with',
#   'a',
#   'philosophical',
#   'flourish',
#   'cato',
#   'throws'],
#  ['high',
#   'time',
#   'to',
#   'get',
#   'to',
#   'sea',
#   'as',
#   'soon',
#   'as',
#   'i',
#   'can',
#   'this',
#   'is',
#   'my',
#   'substitute',
#   'for',
#   'pistol',
#   'and',
#   'ball',
#   'with',
#   'a',
#   'philosophical',
#   'flourish',
#   'cato',
#   'throws',
#   'himself'],
#  ['time',
#   'to',
#   'get',
#   'to',
#   'sea',
#   'as',
#   'soon',
#   'as',
#   'i',
#   'can',
#   'this',
#   'is',
#   'my',
#   'substitute',
#   'for',
#   'pistol',
#   'and',
#   'ball',
#   'with',
#   'a',
#   'philosophical',
#   'flourish',
#   'cato',
#   'throws',
#   'himself',
#   'upon'],
#  ['to',
#   'get',
#   'to',
#   'sea',
#   'as',
#   'soon',
#   'as',
#   'i',
#   'can',
#   'this',
#   'is',
#   'my',
#   'substitute',
#   'for',
#   'pistol',
#   'and',
#   'ball',
#   'with',
#   'a',
#   'philosophical',
#   'flourish',
#   'cato',
#   'throws',
#   'himself',
#   'upon',
#   'his'],
#  ['get',
#   'to',
#   'sea',
#   'as',
#   'soon',
#   'as',
#   'i',
#   'can',
#   'this',
#   'is',
#   'my',
#   'substitute',
#   'for',
#   'pistol',
#   'and',
#   'ball',
#   'with',
#   'a',
#   'philosophical',
#   'flourish',
#   'cato',
#   'throws',
#   'himself',
#   'upon',
#   'his',
#   'sword'],
#  ['to',
#   'sea',
#   'as',
#   'soon',
#   'as',
#   'i',
#   'can',
#   'this',
#   'is',
#   'my',
#   'substitute',
#   'for',
#   'pistol',
#   'and',
#   'ball',
#   'with',
#   'a',
#   'philosophical',
#   'flourish',
#   'cato',
#   'throws',
#   'himself',
#   'upon',
#   'his',
#   'sword',
#   'i'],
#  ['sea',
#   'as',
#   'soon',
#   'as',
#   'i',
#   'can',
#   'this',
#   'is',
#   'my',
#   'substitute',
#   'for',
#   'pistol',
#   'and',
#   'ball',
#   'with',
#   'a',
#   'philosophical',
#   'flourish',
#   'cato',
#   'throws',
#   'himself',
#   'upon',
#   'his',
#   'sword',
#   'i',
#   'quietly'],
#  ['as',
#   'soon',
#   'as',
#   'i',
#   'can',
#   'this',
#   'is',
#   'my',
#   'substitute',
#   'for',
#   'pistol',
#   'and',
#   'ball',
#   'with',
#   'a',
#   'philosophical',
#   'flourish',
#   'cato',
#   'throws',
#   'himself',
#   'upon',
#   'his',
#   'sword',
#   'i',
#   'quietly',
#   'take'],
#  ['soon',
#   'as',
#   'i',
#   'can',
#   'this',
#   'is',
#   'my',
#   'substitute',
#   'for',
#   'pistol',
#   'and',
#   'ball',
#   'with',
#   'a',
#   'philosophical',
#   'flourish',
#   'cato',
#   'throws',
#   'himself',
#   'upon',
#   'his',
#   'sword',
#   'i',
#   'quietly',
#   'take',
#   'to'],
#  ['as',
#   'i',
#   'can',
#   'this',
#   'is',
#   'my',
#   'substitute',
#   'for',
#   'pistol',
#   'and',
#   'ball',
#   'with',
#   'a',
#   'philosophical',
#   'flourish',
#   'cato',
#   'throws',
#   'himself',
#   'upon',
#   'his',
#   'sword',
#   'i',
#   'quietly',
#   'take',
#   'to',
#   'the'],
#  ['i',
#   'can',
#   'this',
#   'is',
#   'my',
#   'substitute',
#   'for',
#   'pistol',
#   'and',
#   'ball',
#   'with',
#   'a',
#   'philosophical',
#   'flourish',
#   'cato',
#   'throws',
#   'himself',
#   'upon',
#   'his',
#   'sword',
#   'i',
#   'quietly',
#   'take',
#   'to',
#   'the',
#   'ship'],
#  ['can',
#   'this',
#   'is',
#   'my',
#   'substitute',
#   'for',
#   'pistol',
#   'and',
#   'ball',
#   'with',
#   'a',
#   'philosophical',
#   'flourish',
#   'cato',
#   'throws',
#   'himself',
#   'upon',
#   'his',
#   'sword',
#   'i',
#   'quietly',
#   'take',
#   'to',
#   'the',
#   'ship',
#   'there'],
#  ['this',
#   'is',
#   'my',
#   'substitute',
#   'for',
#   'pistol',
#   'and',
#   'ball',
#   'with',
#   'a',
#   'philosophical',
#   'flourish',
#   'cato',
#   'throws',
#   'himself',
#   'upon',
#   'his',
#   'sword',
#   'i',
#   'quietly',
#   'take',
#   'to',
#   'the',
#   'ship',
#   'there',
#   'is'],
#  ['is',
#   'my',
#   'substitute',
#   'for',
#   'pistol',
#   'and',
#   'ball',
#   'with',
#   'a',
#   'philosophical',
#   'flourish',
#   'cato',
#   'throws',
#   'himself',
#   'upon',
#   'his',
#   'sword',
#   'i',
#   'quietly',
#   'take',
#   'to',
#   'the',
#   'ship',
#   'there',
#   'is',
#   'nothing'],
#  ['my',
#   'substitute',
#   'for',
#   'pistol',
#   'and',
#   'ball',
#   'with',
#   'a',
#   'philosophical',
#   'flourish',
#   'cato',
#   'throws',
#   'himself',
#   'upon',
#   'his',
#   'sword',
#   'i',
#   'quietly',
#   'take',
#   'to',
#   'the',
#   'ship',
#   'there',
#   'is',
#   'nothing',
#   'surprising'],
#  ['substitute',
#   'for',
#   'pistol',
#   'and',
#   'ball',
#   'with',
#   'a',
#   'philosophical',
#   'flourish',
#   'cato',
#   'throws',
#   'himself',
#   'upon',
#   'his',
#   'sword',
#   'i',
#   'quietly',
#   'take',
#   'to',
#   'the',
#   'ship',
#   'there',
#   'is',
#   'nothing',
#   'surprising',
#   'in'],
#  ['for',
#   'pistol',
#   'and',
#   'ball',
#   'with',
#   'a',
#   'philosophical',
#   'flourish',
#   'cato',
#   'throws',
#   'himself',
#   'upon',
#   'his',
#   'sword',
#   'i',
#   'quietly',
#   'take',
#   'to',
#   'the',
#   'ship',
#   'there',
#   'is',
#   'nothing',
#   'surprising',
#   'in',
#   'this'],
#  ['pistol',
#   'and',
#   'ball',
#   'with',
#   'a',
#   'philosophical',
#   'flourish',
#   'cato',
#   'throws',
#   'himself',
#   'upon',
#   'his',
#   'sword',
#   'i',
#   'quietly',
#   'take',
#   'to',
#   'the',
#   'ship',
#   'there',
#   'is',
#   'nothing',
#   'surprising',
#   'in',
#   'this',
#   'if'],
#  ['and',
#   'ball',
#   'with',
#   'a',
#   'philosophical',
#   'flourish',
#   'cato',
#   'throws',
#   'himself',
#   'upon',
#   'his',
#   'sword',
#   'i',
#   'quietly',
#   'take',
#   'to',
#   'the',
#   'ship',
#   'there',
#   'is',
#   'nothing',
#   'surprising',
#   'in',
#   'this',
#   'if',
#   'they'],
#  ['ball',
#   'with',
#   'a',
#   'philosophical',
#   'flourish',
#   'cato',
#   'throws',
#   'himself',
#   'upon',
#   'his',
#   'sword',
#   'i',
#   'quietly',
#   'take',
#   'to',
#   'the',
#   'ship',
#   'there',
#   'is',
#   'nothing',
#   'surprising',
#   'in',
#   'this',
#   'if',
#   'they',
#   'but'],
#  ['with',
#   'a',
#   'philosophical',
#   'flourish',
#   'cato',
#   'throws',
#   'himself',
#   'upon',
#   'his',
#   'sword',
#   'i',
#   'quietly',
#   'take',
#   'to',
#   'the',
#   'ship',
#   'there',
#   'is',
#   'nothing',
#   'surprising',
#   'in',
#   'this',
#   'if',
#   'they',
#   'but',
#   'knew'],
#  ['a',
#   'philosophical',
#   'flourish',
#   'cato',
#   'throws',
#   'himself',
#   'upon',
#   'his',
#   'sword',
#   'i',
#   'quietly',
#   'take',
#   'to',
#   'the',
#   'ship',
#   'there',
#   'is',
#   'nothing',
#   'surprising',
#   'in',
#   'this',
#   'if',
#   'they',
#   'but',
#   'knew',
#   'it'],
#  ['philosophical',
#   'flourish',
#   'cato',
#   'throws',
#   'himself',
#   'upon',
#   'his',
#   'sword',
#   'i',
#   'quietly',
#   'take',
#   'to',
#   'the',
#   'ship',
#   'there',
#   'is',
#   'nothing',
#   'surprising',
#   'in',
#   'this',
#   'if',
#   'they',
#   'but',
#   'knew',
#   'it',
#   'almost'],
#  ['flourish',
#   'cato',
#   'throws',
#   'himself',
#   'upon',
#   'his',
#   'sword',
#   'i',
#   'quietly',
#   'take',
#   'to',
#   'the',
#   'ship',
#   'there',
#   'is',
#   'nothing',
#   'surprising',
#   'in',
#   'this',
#   'if',
#   'they',
#   'but',
#   'knew',
#   'it',
#   'almost',
#   'all'],
#  ['cato',
#   'throws',
#   'himself',
#   'upon',
#   'his',
#   'sword',
#   'i',
#   'quietly',
#   'take',
#   'to',
#   'the',
#   'ship',
#   'there',
#   'is',
#   'nothing',
#   'surprising',
#   'in',
#   'this',
#   'if',
#   'they',
#   'but',
#   'knew',
#   'it',
#   'almost',
#   'all',
#   'men'],
#  ['throws',
#   'himself',
#   'upon',
#   'his',
#   'sword',
#   'i',
#   'quietly',
#   'take',
#   'to',
#   'the',
#   'ship',
#   'there',
#   'is',
#   'nothing',
#   'surprising',
#   'in',
#   'this',
#   'if',
#   'they',
#   'but',
#   'knew',
#   'it',
#   'almost',
#   'all',
#   'men',
#   'in'],
#  ['himself',
#   'upon',
#   'his',
#   'sword',
#   'i',
#   'quietly',
#   'take',
#   'to',
#   'the',
#   'ship',
#   'there',
#   'is',
#   'nothing',
#   'surprising',
#   'in',
#   'this',
#   'if',
#   'they',
#   'but',
#   'knew',
#   'it',
#   'almost',
#   'all',
#   'men',
#   'in',
#   'their'],
#  ['upon',
#   'his',
#   'sword',
#   'i',
#   'quietly',
#   'take',
#   'to',
#   'the',
#   'ship',
#   'there',
#   'is',
#   'nothing',
#   'surprising',
#   'in',
#   'this',
#   'if',
#   'they',
#   'but',
#   'knew',
#   'it',
#   'almost',
#   'all',
#   'men',
#   'in',
#   'their',
#   'degree'],
#  ['his',
#   'sword',
#   'i',
#   'quietly',
#   'take',
#   'to',
#   'the',
#   'ship',
#   'there',
#   'is',
#   'nothing',
#   'surprising',
#   'in',
#   'this',
#   'if',
#   'they',
#   'but',
#   'knew',
#   'it',
#   'almost',
#   'all',
#   'men',
#   'in',
#   'their',
#   'degree',
#   'some'],
#  ['sword',
#   'i',
#   'quietly',
#   'take',
#   'to',
#   'the',
#   'ship',
#   'there',
#   'is',
#   'nothing',
#   'surprising',
#   'in',
#   'this',
#   'if',
#   'they',
#   'but',
#   'knew',
#   'it',
#   'almost',
#   'all',
#   'men',
#   'in',
#   'their',
#   'degree',
#   'some',
#   'time'],
#  ['i',
#   'quietly',
#   'take',
#   'to',
#   'the',
#   'ship',
#   'there',
#   'is',
#   'nothing',
#   'surprising',
#   'in',
#   'this',
#   'if',
#   'they',
#   'but',
#   'knew',
#   'it',
#   'almost',
#   'all',
#   'men',
#   'in',
#   'their',
#   'degree',
#   'some',
#   'time',
#   'or'],
#  ['quietly',
#   'take',
#   'to',
#   'the',
#   'ship',
#   'there',
#   'is',
#   'nothing',
#   'surprising',
#   'in',
#   'this',
#   'if',
#   'they',
#   'but',
#   'knew',
#   'it',
#   'almost',
#   'all',
#   'men',
#   'in',
#   'their',
#   'degree',
#   'some',
#   'time',
#   'or',
#   'other'],
#  ['take',
#   'to',
#   'the',
#   'ship',
#   'there',
#   'is',
#   'nothing',
#   'surprising',
#   'in',
#   'this',
#   'if',
#   'they',
#   'but',
#   'knew',
#   'it',
#   'almost',
#   'all',
#   'men',
#   'in',
#   'their',
#   'degree',
#   'some',
#   'time',
#   'or',
#   'other',
#   'cherish'],
#  ['to',
#   'the',
#   'ship',
#   'there',
#   'is',
#   'nothing',
#   'surprising',
#   'in',
#   'this',
#   'if',
#   'they',
#   'but',
#   'knew',
#   'it',
#   'almost',
#   'all',
#   'men',
#   'in',
#   'their',
#   'degree',
#   'some',
#   'time',
#   'or',
#   'other',
#   'cherish',
#   'very'],
#  ['the',
#   'ship',
#   'there',
#   'is',
#   'nothing',
#   'surprising',
#   'in',
#   'this',
#   'if',
#   'they',
#   'but',
#   'knew',
#   'it',
#   'almost',
#   'all',
#   'men',
#   'in',
#   'their',
#   'degree',
#   'some',
#   'time',
#   'or',
#   'other',
#   'cherish',
#   'very',
#   'nearly'],
#  ['ship',
#   'there',
#   'is',
#   'nothing',
#   'surprising',
#   'in',
#   'this',
#   'if',
#   'they',
#   'but',
#   'knew',
#   'it',
#   'almost',
#   'all',
#   'men',
#   'in',
#   'their',
#   'degree',
#   'some',
#   'time',
#   'or',
#   'other',
#   'cherish',
#   'very',
#   'nearly',
#   'the'],
#  ['there',
#   'is',
#   'nothing',
#   'surprising',
#   'in',
#   'this',
#   'if',
#   'they',
#   'but',
#   'knew',
#   'it',
#   'almost',
#   'all',
#   'men',
#   'in',
#   'their',
#   'degree',
#   'some',
#   'time',
#   'or',
#   'other',
#   'cherish',
#   'very',
#   'nearly',
#   'the',
#   'same'],
#  ['is',
#   'nothing',
#   'surprising',
#   'in',
#   'this',
#   'if',
#   'they',
#   'but',
#   'knew',
#   'it',
#   'almost',
#   'all',
#   'men',
#   'in',
#   'their',
#   'degree',
#   'some',
#   'time',
#   'or',
#   'other',
#   'cherish',
#   'very',
#   'nearly',
#   'the',
#   'same',
#   'feelings'],
#  ['nothing',
#   'surprising',
#   'in',
#   'this',
#   'if',
#   'they',
#   'but',
#   'knew',
#   'it',
#   'almost',
#   'all',
#   'men',
#   'in',
#   'their',
#   'degree',
#   'some',
#   'time',
#   'or',
#   'other',
#   'cherish',
#   'very',
#   'nearly',
#   'the',
#   'same',
#   'feelings',
#   'towards'],
#  ['surprising',
#   'in',
#   'this',
#   'if',
#   'they',
#   'but',
#   'knew',
#   'it',
#   'almost',
#   'all',
#   'men',
#   'in',
#   'their',
#   'degree',
#   'some',
#   'time',
#   'or',
#   'other',
#   'cherish',
#   'very',
#   'nearly',
#   'the',
#   'same',
#   'feelings',
#   'towards',
#   'the'],
#  ['in',
#   'this',
#   'if',
#   'they',
#   'but',
#   'knew',
#   'it',
#   'almost',
#   'all',
#   'men',
#   'in',
#   'their',
#   'degree',
#   'some',
#   'time',
#   'or',
#   'other',
#   'cherish',
#   'very',
#   'nearly',
#   'the',
#   'same',
#   'feelings',
#   'towards',
#   'the',
#   'ocean'],
#  ['this',
#   'if',
#   'they',
#   'but',
#   'knew',
#   'it',
#   'almost',
#   'all',
#   'men',
#   'in',
#   'their',
#   'degree',
#   'some',
#   'time',
#   'or',
#   'other',
#   'cherish',
#   'very',
#   'nearly',
#   'the',
#   'same',
#   'feelings',
#   'towards',
#   'the',
#   'ocean',
#   'with'],
#  ['if',
#   'they',
#   'but',
#   'knew',
#   'it',
#   'almost',
#   'all',
#   'men',
#   'in',
#   'their',
#   'degree',
#   'some',
#   'time',
#   'or',
#   'other',
#   'cherish',
#   'very',
#   'nearly',
#   'the',
#   'same',
#   'feelings',
#   'towards',
#   'the',
#   'ocean',
#   'with',
#   'me'],
#  ['they',
#   'but',
#   'knew',
#   'it',
#   'almost',
#   'all',
#   'men',
# ...
#   'in',
#   'all',
#   'rivers',
#   'and',
#   'oceans',
#   'it',
#   'is',
#   'the'],
#  ['saw',
#   'in',
#   'the',
#   'fountain',
#   'plunged',
#   'into',
#   'it',
#   'and',
#   'was',
#   'drowned',
#   'but',
#   'that',
#   'same',
#   'image',
#   'we',
#   'ourselves',
#   'see',
#   'in',
#   'all',
#   'rivers',
#   'and',
#   'oceans',
#   'it',
#   'is',
#   'the',
#   'image'],
#  ['in',
#   'the',
#   'fountain',
#   'plunged',
#   'into',
#   'it',
#   'and',
#   'was',
#   'drowned',
#   'but',
#   'that',
#   'same',
#   'image',
#   'we',
#   'ourselves',
#   'see',
#   'in',
#   'all',
#   'rivers',
#   'and',
#   'oceans',
#   'it',
#   'is',
#   'the',
#   'image',
#   'of'],
#  ['the',
#   'fountain',
#   'plunged',
#   'into',
#   'it',
#   'and',
#   'was',
#   'drowned',
#   'but',
#   'that',
#   'same',
#   'image',
#   'we',
#   'ourselves',
#   'see',
#   'in',
#   'all',
#   'rivers',
#   'and',
#   'oceans',
#   'it',
#   'is',
#   'the',
#   'image',
#   'of',
#   'the'],
#  ['fountain',
#   'plunged',
#   'into',
#   'it',
#   'and',
#   'was',
#   'drowned',
#   'but',
#   'that',
#   'same',
#   'image',
#   'we',
#   'ourselves',
#   'see',
#   'in',
#   'all',
#   'rivers',
#   'and',
#   'oceans',
#   'it',
#   'is',
#   'the',
#   'image',
#   'of',
#   'the',
#   'ungraspable'],
#  ['plunged',
#   'into',
#   'it',
#   'and',
#   'was',
#   'drowned',
#   'but',
#   'that',
#   'same',
#   'image',
#   'we',
#   'ourselves',
#   'see',
#   'in',
#   'all',
#   'rivers',
#   'and',
#   'oceans',
#   'it',
#   'is',
#   'the',
#   'image',
#   'of',
#   'the',
#   'ungraspable',
#   'phantom'],
#  ['into',
#   'it',
#   'and',
#   'was',
#   'drowned',
#   'but',
#   'that',
#   'same',
#   'image',
#   'we',
#   'ourselves',
#   'see',
#   'in',
#   'all',
#   'rivers',
#   'and',
#   'oceans',
#   'it',
#   'is',
#   'the',
#   'image',
#   'of',
#   'the',
#   'ungraspable',
#   'phantom',
#   'of'],
#  ['it',
#   'and',
#   'was',
#   'drowned',
#   'but',
#   'that',
#   'same',
#   'image',
#   'we',
#   'ourselves',
#   'see',
#   'in',
#   'all',
#   'rivers',
#   'and',
#   'oceans',
#   'it',
#   'is',
#   'the',
#   'image',
#   'of',
#   'the',
#   'ungraspable',
#   'phantom',
#   'of',
#   'life'],
#  ['and',
#   'was',
#   'drowned',
#   'but',
#   'that',
#   'same',
#   'image',
#   'we',
#   'ourselves',
#   'see',
#   'in',
#   'all',
#   'rivers',
#   'and',
#   'oceans',
#   'it',
#   'is',
#   'the',
#   'image',
#   'of',
#   'the',
#   'ungraspable',
#   'phantom',
#   'of',
#   'life',
#   'and'],
#  ['was',
#   'drowned',
#   'but',
#   'that',
#   'same',
#   'image',
#   'we',
#   'ourselves',
#   'see',
#   'in',
#   'all',
#   'rivers',
#   'and',
#   'oceans',
#   'it',
#   'is',
#   'the',
#   'image',
#   'of',
#   'the',
#   'ungraspable',
#   'phantom',
#   'of',
#   'life',
#   'and',
#   'this'],
#  ['drowned',
#   'but',
#   'that',
#   'same',
#   'image',
#   'we',
#   'ourselves',
#   'see',
#   'in',
#   'all',
#   'rivers',
#   'and',
#   'oceans',
#   'it',
#   'is',
#   'the',
#   'image',
#   'of',
#   'the',
#   'ungraspable',
#   'phantom',
#   'of',
#   'life',
#   'and',
#   'this',
#   'is'],
#  ['but',
#   'that',
#   'same',
#   'image',
#   'we',
#   'ourselves',
#   'see',
#   'in',
#   'all',
#   'rivers',
#   'and',
#   'oceans',
#   'it',
#   'is',
#   'the',
#   'image',
#   'of',
#   'the',
#   'ungraspable',
#   'phantom',
#   'of',
#   'life',
#   'and',
#   'this',
#   'is',
#   'the'],
#  ['that',
#   'same',
#   'image',
#   'we',
#   'ourselves',
#   'see',
#   'in',
#   'all',
#   'rivers',
#   'and',
#   'oceans',
#   'it',
#   'is',
#   'the',
#   'image',
#   'of',
#   'the',
#   'ungraspable',
#   'phantom',
#   'of',
#   'life',
#   'and',
#   'this',
#   'is',
#   'the',
#   'key'],
#  ['same',
#   'image',
#   'we',
#   'ourselves',
#   'see',
#   'in',
#   'all',
#   'rivers',
#   'and',
#   'oceans',
#   'it',
#   'is',
#   'the',
#   'image',
#   'of',
#   'the',
#   'ungraspable',
#   'phantom',
#   'of',
#   'life',
#   'and',
#   'this',
#   'is',
#   'the',
#   'key',
#   'to'],
#  ['image',
#   'we',
#   'ourselves',
#   'see',
#   'in',
#   'all',
#   'rivers',
#   'and',
#   'oceans',
#   'it',
#   'is',
#   'the',
#   'image',
#   'of',
#   'the',
#   'ungraspable',
#   'phantom',
#   'of',
#   'life',
#   'and',
#   'this',
#   'is',
#   'the',
#   'key',
#   'to',
#   'it'],
#  ['we',
#   'ourselves',
#   'see',
#   'in',
#   'all',
#   'rivers',
#   'and',
#   'oceans',
#   'it',
#   'is',
#   'the',
#   'image',
#   'of',
#   'the',
#   'ungraspable',
#   'phantom',
#   'of',
#   'life',
#   'and',
#   'this',
#   'is',
#   'the',
#   'key',
#   'to',
#   'it',
#   'all'],
#  ['ourselves',
#   'see',
#   'in',
#   'all',
#   'rivers',
#   'and',
#   'oceans',
#   'it',
#   'is',
#   'the',
#   'image',
#   'of',
#   'the',
#   'ungraspable',
#   'phantom',
#   'of',
#   'life',
#   'and',
#   'this',
#   'is',
#   'the',
#   'key',
#   'to',
#   'it',
#   'all',
#   'now'],
#  ['see',
#   'in',
#   'all',
#   'rivers',
#   'and',
#   'oceans',
#   'it',
#   'is',
#   'the',
#   'image',
#   'of',
#   'the',
#   'ungraspable',
#   'phantom',
#   'of',
#   'life',
#   'and',
#   'this',
#   'is',
#   'the',
#   'key',
#   'to',
#   'it',
#   'all',
#   'now',
#   'when'],
#  ['in',
#   'all',
#   'rivers',
#   'and',
#   'oceans',
#   'it',
#   'is',
#   'the',
#   'image',
#   'of',
#   'the',
#   'ungraspable',
#   'phantom',
#   'of',
#   'life',
#   'and',
#   'this',
#   'is',
#   'the',
#   'key',
#   'to',
#   'it',
#   'all',
#   'now',
#   'when',
#   'i'],
#  ['all',
#   'rivers',
#   'and',
#   'oceans',
#   'it',
#   'is',
#   'the',
#   'image',
#   'of',
#   'the',
#   'ungraspable',
#   'phantom',
#   'of',
#   'life',
#   'and',
#   'this',
#   'is',
#   'the',
#   'key',
#   'to',
#   'it',
#   'all',
#   'now',
#   'when',
#   'i',
#   'say'],
#  ['rivers',
#   'and',
#   'oceans',
#   'it',
#   'is',
#   'the',
#   'image',
#   'of',
#   'the',
#   'ungraspable',
#   'phantom',
#   'of',
#   'life',
#   'and',
#   'this',
#   'is',
#   'the',
#   'key',
#   'to',
#   'it',
#   'all',
#   'now',
#   'when',
#   'i',
#   'say',
#   'that'],
#  ['and',
#   'oceans',
#   'it',
#   'is',
#   'the',
#   'image',
#   'of',
#   'the',
#   'ungraspable',
#   'phantom',
#   'of',
#   'life',
#   'and',
#   'this',
#   'is',
#   'the',
#   'key',
#   'to',
#   'it',
#   'all',
#   'now',
#   'when',
#   'i',
#   'say',
#   'that',
#   'i'],
#  ['oceans',
#   'it',
#   'is',
#   'the',
#   'image',
#   'of',
#   'the',
#   'ungraspable',
#   'phantom',
#   'of',
#   'life',
#   'and',
#   'this',
#   'is',
#   'the',
#   'key',
#   'to',
#   'it',
#   'all',
#   'now',
#   'when',
#   'i',
#   'say',
#   'that',
#   'i',
#   'am'],
#  ['it',
#   'is',
#   'the',
#   'image',
#   'of',
#   'the',
#   'ungraspable',
#   'phantom',
#   'of',
#   'life',
#   'and',
#   'this',
#   'is',
#   'the',
#   'key',
#   'to',
#   'it',
#   'all',
#   'now',
#   'when',
#   'i',
#   'say',
#   'that',
#   'i',
#   'am',
#   'in'],
#  ['is',
#   'the',
#   'image',
#   'of',
#   'the',
#   'ungraspable',
#   'phantom',
#   'of',
#   'life',
#   'and',
#   'this',
#   'is',
#   'the',
#   'key',
#   'to',
#   'it',
#   'all',
#   'now',
#   'when',
#   'i',
#   'say',
#   'that',
#   'i',
#   'am',
#   'in',
#   'the'],
#  ['the',
#   'image',
#   'of',
#   'the',
#   'ungraspable',
#   'phantom',
#   'of',
#   'life',
#   'and',
#   'this',
#   'is',
#   'the',
#   'key',
#   'to',
#   'it',
#   'all',
#   'now',
#   'when',
#   'i',
#   'say',
#   'that',
#   'i',
#   'am',
#   'in',
#   'the',
#   'habit'],
#  ['image',
#   'of',
#   'the',
#   'ungraspable',
#   'phantom',
#   'of',
#   'life',
#   'and',
#   'this',
#   'is',
#   'the',
#   'key',
#   'to',
#   'it',
#   'all',
#   'now',
#   'when',
#   'i',
#   'say',
#   'that',
#   'i',
#   'am',
#   'in',
#   'the',
#   'habit',
#   'of'],
#  ['of',
#   'the',
#   'ungraspable',
#   'phantom',
#   'of',
#   'life',
#   'and',
#   'this',
#   'is',
#   'the',
#   'key',
#   'to',
#   'it',
#   'all',
#   'now',
#   'when',
#   'i',
#   'say',
#   'that',
#   'i',
#   'am',
#   'in',
#   'the',
#   'habit',
#   'of',
#   'going'],
#  ['the',
#   'ungraspable',
#   'phantom',
#   'of',
#   'life',
#   'and',
#   'this',
#   'is',
#   'the',
#   'key',
#   'to',
#   'it',
#   'all',
#   'now',
#   'when',
#   'i',
#   'say',
#   'that',
#   'i',
#   'am',
#   'in',
#   'the',
#   'habit',
#   'of',
#   'going',
#   'to'],
#  ['ungraspable',
#   'phantom',
#   'of',
#   'life',
#   'and',
#   'this',
#   'is',
#   'the',
#   'key',
#   'to',
#   'it',
#   'all',
#   'now',
#   'when',
#   'i',
#   'say',
#   'that',
#   'i',
#   'am',
#   'in',
#   'the',
#   'habit',
#   'of',
#   'going',
#   'to',
#   'sea'],
#  ['phantom',
#   'of',
#   'life',
#   'and',
#   'this',
#   'is',
#   'the',
#   'key',
#   'to',
#   'it',
#   'all',
#   'now',
#   'when',
#   'i',
#   'say',
#   'that',
#   'i',
#   'am',
#   'in',
#   'the',
#   'habit',
#   'of',
#   'going',
#   'to',
#   'sea',
#   'whenever'],
#  ['of',
#   'life',
#   'and',
#   'this',
#   'is',
#   'the',
#   'key',
#   'to',
#   'it',
#   'all',
#   'now',
#   'when',
#   'i',
#   'say',
#   'that',
#   'i',
#   'am',
#   'in',
#   'the',
#   'habit',
#   'of',
#   'going',
#   'to',
#   'sea',
#   'whenever',
#   'i'],
#  ['life',
#   'and',
#   'this',
#   'is',
#   'the',
#   'key',
#   'to',
#   'it',
#   'all',
#   'now',
#   'when',
#   'i',
#   'say',
#   'that',
#   'i',
#   'am',
#   'in',
#   'the',
#   'habit',
#   'of',
#   'going',
#   'to',
#   'sea',
#   'whenever',
#   'i',
#   'begin'],
#  ['and',
#   'this',
#   'is',
#   'the',
#   'key',
#   'to',
#   'it',
#   'all',
#   'now',
#   'when',
#   'i',
#   'say',
#   'that',
#   'i',
#   'am',
#   'in',
#   'the',
#   'habit',
#   'of',
#   'going',
#   'to',
#   'sea',
#   'whenever',
#   'i',
#   'begin',
#   'to'],
#  ['this',
#   'is',
#   'the',
#   'key',
#   'to',
#   'it',
#   'all',
#   'now',
#   'when',
#   'i',
#   'say',
#   'that',
#   'i',
#   'am',
#   'in',
#   'the',
#   'habit',
#   'of',
#   'going',
#   'to',
#   'sea',
#   'whenever',
#   'i',
#   'begin',
#   'to',
#   'grow'],
#  ['is',
#   'the',
#   'key',
#   'to',
#   'it',
#   'all',
#   'now',
#   'when',
#   'i',
#   'say',
#   'that',
#   'i',
#   'am',
#   'in',
#   'the',
#   'habit',
#   'of',
#   'going',
#   'to',
#   'sea',
#   'whenever',
#   'i',
#   'begin',
#   'to',
#   'grow',
#   'hazy'],
#  ['the',
#   'key',
#   'to',
#   'it',
#   'all',
#   'now',
#   'when',
#   'i',
#   'say',
#   'that',
#   'i',
#   'am',
#   'in',
#   'the',
#   'habit',
#   'of',
#   'going',
#   'to',
#   'sea',
#   'whenever',
#   'i',
#   'begin',
#   'to',
#   'grow',
#   'hazy',
#   'about'],
#  ['key',
#   'to',
#   'it',
#   'all',
#   'now',
#   'when',
#   'i',
#   'say',
#   'that',
#   'i',
#   'am',
#   'in',
#   'the',
#   'habit',
#   'of',
#   'going',
#   'to',
#   'sea',
#   'whenever',
#   'i',
#   'begin',
#   'to',
#   'grow',
#   'hazy',
#   'about',
#   'the'],
#  ['to',
#   'it',
#   'all',
#   'now',
#   'when',
#   'i',
#   'say',
#   'that',
#   'i',
#   'am',
#   'in',
#   'the',
#   'habit',
#   'of',
#   'going',
#   'to',
#   'sea',
#   'whenever',
#   'i',
#   'begin',
#   'to',
#   'grow',
#   'hazy',
#   'about',
#   'the',
#   'eyes'],
#  ['it',
#   'all',
#   'now',
#   'when',
#   'i',
#   'say',
#   'that',
#   'i',
#   'am',
#   'in',
#   'the',
#   'habit',
#   'of',
#   'going',
#   'to',
#   'sea',
#   'whenever',
#   'i',
#   'begin',
#   'to',
#   'grow',
#   'hazy',
#   'about',
#   'the',
#   'eyes',
#   'and'],
#  ['all',
#   'now',
#   'when',
#   'i',
#   'say',
#   'that',
#   'i',
#   'am',
#   'in',
#   'the',
#   'habit',
#   'of',
#   'going',
#   'to',
#   'sea',
#   'whenever',
#   'i',
#   'begin',
#   'to',
#   'grow',
#   'hazy',
#   'about',
#   'the',
#   'eyes',
#   'and',
#   'begin'],
#  ['now',
#   'when',
#   'i',
#   'say',
#   'that',
#   'i',
#   'am',
#   'in',
#   'the',
#   'habit',
#   'of',
#   'going',
#   'to',
#   'sea',
#   'whenever',
#   'i',
#   'begin',
#   'to',
#   'grow',
#   'hazy',
#   'about',
#   'the',
#   'eyes',
#   'and',
#   'begin',
#   'to'],
#  ['when',
#   'i',
#   'say',
#   'that',
#   'i',
#   'am',
#   'in',
#   'the',
#   'habit',
#   'of',
#   'going',
#   'to',
#   'sea',
#   'whenever',
#   'i',
#   'begin',
#   'to',
#   'grow',
#   'hazy',
#   'about',
#   'the',
#   'eyes',
#   'and',
#   'begin',
#   'to',
#   'be'],
#  ['i',
#   'say',
#   'that',
#   'i',
#   'am',
#   'in',
#   'the',
#   'habit',
#   'of',
#   'going',
#   'to',
#   'sea',
#   'whenever',
#   'i',
#   'begin',
#   'to',
#   'grow',
#   'hazy',
#   'about',
#   'the',
#   'eyes',
#   'and',
#   'begin',
#   'to',
#   'be',
#   'over'],
#  ['say',
#   'that',
#   'i',
#   'am',
#   'in',
#   'the',
#   'habit',
#   'of',
#   'going',
#   'to',
#   'sea',
#   'whenever',
#   'i',
#   'begin',
#   'to',
#   'grow',
#   'hazy',
#   'about',
#   'the',
#   'eyes',
#   'and',
#   'begin',
#   'to',
#   'be',
#   'over',
#   'conscious'],
#  ['that',
#   'i',
#   'am',
#   'in',
#   'the',
#   'habit',
#   'of',
#   'going',
#   'to',
#   'sea',
#   'whenever',
#   'i',
#   'begin',
#   'to',
#   'grow',
#   'hazy',
#   'about',
#   'the',
#   'eyes',
#   'and',
#   'begin',
#   'to',
#   'be',
#   'over',
#   'conscious',
#   'of'],
#  ['i',
#   'am',
#   'in',
#   'the',
#   'habit',
#   'of',
#   'going',
#   'to',
#   'sea',
#   'whenever',
#   'i',
#   'begin',
#   'to',
#   'grow',
#   'hazy',
#   'about',
#   'the',
#   'eyes',
#   'and',
#   'begin',
#   'to',
#   'be',
#   'over',
#   'conscious',
#   'of',
#   'my'],
#  ['am',
#   'in',
#   'the',
#   'habit',
#   'of',
#   'going',
#   'to',
#   'sea',
#   'whenever',
#   'i',
#   'begin',
#   'to',
#   'grow',
#   'hazy',
#   'about',
#   'the',
#   'eyes',
#   'and',
#   'begin',
#   'to',
#   'be',
#   'over',
#   'conscious',
#   'of',
#   'my',
#   'lungs'],
#  ['in',
#   'the',
#   'habit',
#   'of',
#   'going',
#   'to',
#   'sea',
#   'whenever',
#   'i',
#   'begin',
#   'to',
#   'grow',
#   'hazy',
#   'about',
#   'the',
#   'eyes',
#   'and',
#   'begin',
#   'to',
#   'be',
#   'over',
#   'conscious',
#   'of',
#   'my',
#   'lungs',
#   'i'],
#  ['the',
#   'habit',
#   'of',
#   'going',
#   'to',
#   'sea',
#   'whenever',
#   'i',
#   'begin',
#   'to',
#   'grow',
#   'hazy',
#   'about',
#   'the',
#   'eyes',
#   'and',
#   'begin',
#   'to',
#   'be',
#   'over',
#   'conscious',
#   'of',
#   'my',
#   'lungs',
#   'i',
#   'do'],
#  ['habit',
#   'of',
#   'going',
#   'to',
#   'sea',
#   'whenever',
#   'i',
#   'begin',
#   'to',
#   'grow',
#   'hazy',
#   'about',
#   'the',
#   'eyes',
#   'and',
#   'begin',
#   'to',
#   'be',
#   'over',
#   'conscious',
#   'of',
#   'my',
#   'lungs',
#   'i',
#   'do',
#   'not'],
#  ['of',
#   'going',
#   'to',
#   'sea',
#   'whenever',
#   'i',
#   'begin',
#   'to',
#   'grow',
#   'hazy',
#   'about',
#   'the',
#   'eyes',
#   'and',
#   'begin',
#   'to',
#   'be',
#   'over',
#   'conscious',
#   'of',
#   'my',
#   'lungs',
#   'i',
#   'do',
#   'not',
#   'mean'],
#  ['going',
#   'to',
#   'sea',
#   'whenever',
#   'i',
#   'begin',
#   'to',
#   'grow',
#   'hazy',
#   'about',
#   'the',
#   'eyes',
#   'and',
#   'begin',
#   'to',
#   'be',
#   'over',
#   'conscious',
#   'of',
#   'my',
#   'lungs',
#   'i',
#   'do',
#   'not',
#   'mean',
#   'to'],
#  ['to',
#   'sea',
#   'whenever',
#   'i',
#   'begin',
#   'to',
#   'grow',
#   'hazy',
#   'about',
#   'the',
#   'eyes',
#   'and',
#   'begin',
#   'to',
#   'be',
#   'over',
#   'conscious',
#   'of',
#   'my',
#   'lungs',
#   'i',
#   'do',
#   'not',
#   'mean',
#   'to',
#   'have'],
#  ['sea',
#   'whenever',
#   'i',
#   'begin',
#   'to',
#   'grow',
#   'hazy',
#   'about',
#   'the',
#   'eyes',
#   'and',
#   'begin',
#   'to',
#   'be',
#   'over',
#   'conscious',
#   'of',
#   'my',
#   'lungs',
#   'i',
#   'do',
#   'not',
#   'mean',
#   'to',
#   'have',
#   'it'],
#  ['whenever',
#   'i',
#   'begin',
#   'to',
#   'grow',
#   'hazy',
#   'about',
#   'the',
#   'eyes',
#   'and',
#   'begin',
#   'to',
#   'be',
#   'over',
#   'conscious',
#   'of',
#   'my',
#   'lungs',
#   'i',
#   'do',
#   'not',
#   'mean',
#   'to',
#   'have',
#   'it',
#   'inferred'],
#  ['i',
#   'begin',
#   'to',
#   'grow',
#   'hazy',
#   'about',
#   'the',
#   'eyes',
#   'and',
#   'begin',
#   'to',
#   'be',
#   'over',
#   'conscious',
#   'of',
#   'my',
#   'lungs',
#   'i',
#   'do',
#   'not',
#   'mean',
#   'to',
#   'have',
#   'it',
#   'inferred',
#   'that'],
#  ['begin',
#   'to',
#   'grow',
#   'hazy',
#   'about',
#   'the',
#   'eyes',
#   'and',
#   'begin',
#   'to',
#   'be',
#   'over',
#   'conscious',
#   'of',
#   'my',
#   'lungs',
#   'i',
#   'do',
#   'not',
#   'mean',
#   'to',
#   'have',
#   'it',
#   'inferred',
#   'that',
#   'i'],
#  ['to',
#   'grow',
#   'hazy',
#   'about',
#   'the',
#   'eyes',
#   'and',
#   'begin',
#   'to',
#   'be',
#   'over',
#   'conscious',
#   'of',
#   'my',
#   'lungs',
#   'i',
#   'do',
#   'not',
#   'mean',
#   'to',
#   'have',
#   'it',
#   'inferred',
#   'that',
#   'i',
#   'ever'],
#  ['grow',
#   'hazy',
#   'about',
#   'the',
#   'eyes',
#   'and',
#   'begin',
#   'to',
#   'be',
#   'over',
#   'conscious',
#   'of',
#   'my',
#   'lungs',
#   'i',
#   'do',
#   'not',
#   'mean',
#   'to',
#   'have',
#   'it',
#   'inferred',
#   'that',
#   'i',
#   'ever',
#   'go'],
#  ['hazy',
#   'about',
#   'the',
#   'eyes',
#   'and',
#   'begin',
#   'to',
#   'be',
#   'over',
#   'conscious',
#   'of',
#   'my',
#   'lungs',
#   'i',
#   'do',
#   'not',
#   'mean',
#   'to',
#   'have',
#   'it',
#   'inferred',
#   'that',
#   'i',
#   'ever',
#   'go',
#   'to'],
#  ['about',
#   'the',
#   'eyes',
#   'and',
#   'begin',
#   'to',
#   'be',
#   'over',
#   'conscious',
#   'of',
#   'my',
#   'lungs',
#   'i',
#   'do',
#   'not',
#   'mean',
#   'to',
#   'have',
#   'it',
#   'inferred',
#   'that',
#   'i',
#   'ever',
#   'go',
#   'to',
#   'sea'],
#  ['the',
#   'eyes',
#   'and',
#   'begin',
#   'to',
#   'be',
#   'over',
#   'conscious',
#   'of',
#   'my',
#   'lungs',
#   'i',
#   'do',
#   'not',
#   'mean',
#   'to',
#   'have',
#   'it',
#   'inferred',
#   'that',
#   'i',
#   'ever',
#   'go',
#   'to',
#   'sea',
#   'as'],
#  ['eyes',
#   'and',
#   'begin',
#   'to',
#   'be',
#   'over',
#   'conscious',
#   'of',
#   'my',
#   'lungs',
#   'i',
#   'do',
#   'not',
#   'mean',
#   'to',
#   'have',
#   'it',
#   'inferred',
#   'that',
#   'i',
#   'ever',
#   'go',
#   'to',
#   'sea',
#   'as',
#   'a'],
#  ['and',
#   'begin',
#   'to',
#   'be',
#   'over',
#   'conscious',
#   'of',
#   'my',
#   'lungs',
#   'i',
#   'do',
#   'not',
#   'mean',
#   'to',
#   'have',
#   'it',
#   'inferred',
#   'that',
#   'i',
#   'ever',
#   'go',
#   'to',
#   'sea',
#   'as',
#   'a',
#   'passenger'],
#  ...]

# %%
seed_text = " ".join(text_sequences[0])

# %%
seed_text
# Out:
# 'call me ishmael some years ago never mind how long precisely having little or no money in my purse and nothing particular to interest me on'

# %%
generate_text(model,tokenizer,seq_len,seed_text=seed_text,num_gen_words=25)
# Out:
# 'shore i thought you may accustomed to understand a whalin and had a good frosty principle in doom was beating a small degree civilized by'
